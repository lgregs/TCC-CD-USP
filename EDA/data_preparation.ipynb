# %% [markdown]
# # Preparação dos dados para o Modelo.

# %%
import pandas as pd
import numpy as np
# df pivotado
df=pd.read_csv('C:/Users/gregorio/TCC-CD-USP/archives/df_wide.csv')
df.head()
# Out:
#   CompanyCode   Ano    Investimentos em Capital Fixo  (Subtotal)  \
# 0        ADEL  2008                              NaN  27018810.5
# 1        ADEL  2009                              NaN  27018810.5
# 2        ADEL  2010                              NaN  33872750.5
# 3        ADEL  2011                              NaN  43914250.0
# 4        ADEL  2012                              NaN  54610053.0
#
#    Ajuste de Capital de Participação Mútua (-)  Ajustes:  \
# 0                                          0.0       NaN
# 1                                          0.0       NaN
# 2                                          0.0       NaN
# 3                                          0.0       NaN
# 4                                          0.0       NaN
#
#    Amortização e Quotas de Exaustão  Ativo Fiscal Diferido  \
# 0                               NaN                    0.0
# 1                               NaN                    0.0
# 2                               NaN                    0.0
# 3                               NaN               113998.0
# 4                               NaN               346418.0
#
#    Ativos Circulantes  Ativos Imobilizados  ...  \
# 0          45582654.0           14716940.0  ...
# 1          45582654.0           14716940.0  ...
# 2          58621451.0           13861696.0  ...
# 3          75550839.0           14762743.0  ...
# 4          93484162.0           16136254.0  ...
#
#    Receitas de Atividades de Investimento  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    Reservas Restritas Separadas do Lucro  \
# 0                              2957664.0
# 1                              2957664.0
# 2                              4729678.0
# 3                              5450104.0
# 4                              6378203.0
#
#    Reservas de Capital de Emissão de Ações  TOTAL DE ATIVOS  \
# 0                                      0.0       60753401.0
# 1                                      0.0       60753401.0
# 2                                      0.0       73046265.0
# 3                                      0.0       91031840.0
# 4                                      0.0      111340127.0
#
#    TOTAL DO PASSIVO E PATRIMÔNICO LÍQUIDO  \
# 0                              60753401.0
# 1                              60753401.0
# 2                              73046265.0
# 3                              91031840.0
# 4                             111340127.0
#
#    Valores de Caixa no Início do Período  Variação nas Dívidas Financeiras  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
#
#    Variação no Caixa e Equivalentes  Vendas Domésticas  Vendas Internacionais
# 0                               NaN         87260709.0              4865016.0
# 1                               NaN         87260709.0              4865016.0
# 2                               NaN        104427004.0              5399918.0
# 3                               NaN        132355741.0              6157158.0
# 4                               NaN        162911678.0              7611179.0
#
# [5 rows x 109 columns]

# %%
# Drop das colunas >95% zeradas ou NA
threshold = 0.45
cols_to_drop = [
    col for col in df.columns
    if (df[col].isna().mean() > threshold) or ((df[col] == 0).mean() > threshold)
]
df_clean = df.drop(columns=cols_to_drop)

# %%
df_clean
# Out:
#      CompanyCode   Ano    Investimentos em Capital Fixo    (Subtotal)  \
# 0           ADEL  2008                              NaN  2.701881e+07
# 1           ADEL  2009                              NaN  2.701881e+07
# 2           ADEL  2010                              NaN  3.387275e+07
# 3           ADEL  2011                              NaN  4.391425e+07
# 4           ADEL  2012                              NaN  5.461005e+07
# ...          ...   ...                              ...           ...
# 3840       ZOREN  2020                    -1.881500e+08  6.037722e+09
# 3841       ZOREN  2021                    -3.353620e+08  7.986534e+09
# 3842       ZOREN  2022                    -9.923150e+08  3.006555e+10
# 3843       ZOREN  2023                    -1.219082e+09  2.698698e+10
# 3844       ZOREN  2024                    -1.202219e+09  1.677384e+10
#
#           Ajustes:  Amortização e Quotas de Exaustão  Ativo Fiscal Diferido  \
# 0              NaN                               NaN           0.000000e+00
# 1              NaN                               NaN           0.000000e+00
# 2              NaN                               NaN           0.000000e+00
# 3              NaN                               NaN           1.139980e+05
# 4              NaN                               NaN           3.464180e+05
# ...            ...                               ...                    ...
# 3840  1.872685e+09                      6.032930e+08           4.888430e+08
# 3841  2.968941e+09                      6.905980e+08           6.717470e+08
# 3842 -7.099029e+09                      3.668976e+09           1.700569e+09
# 3843 -1.209898e+10                      6.194368e+09           6.855687e+09
# 3844 -7.936120e+08                      4.827761e+09           1.057653e+10
#
#       Ativos Circulantes  Ativos Imobilizados  Ativos Intangíveis  ...  \
# 0           4.558265e+07         1.471694e+07        5.988400e+04  ...
# 1           4.558265e+07         1.471694e+07        5.988400e+04  ...
# 2           5.862145e+07         1.386170e+07        1.258040e+05  ...
# 3           7.555084e+07         1.476274e+07        1.452930e+05  ...
# 4           9.348416e+07         1.613625e+07        1.755500e+05  ...
# ...                  ...                  ...                 ...  ...
# 3840        4.047594e+09         1.061079e+10        1.506887e+09  ...
# 3841        6.471306e+09         1.878782e+10        1.501186e+09  ...
# 3842        2.259070e+10         5.698022e+10        8.819497e+09  ...
# 3843        2.862619e+10         5.836801e+10        1.106112e+10  ...
# 3844        1.341005e+10         5.496624e+10        1.048758e+10  ...
#
#       Receitas Financeiras (Não Operacionais)  \
# 0                                5.111900e+05
# 1                                5.111900e+05
# 2                                4.216040e+05
# 3                                9.681330e+05
# 4                                1.373916e+06
# ...                                       ...
# 3840                             9.817280e+08
# 3841                             2.516698e+09
# 3842                             8.832234e+09
# 3843                             1.328357e+10
# 3844                             4.910232e+09
#
#       Receitas de Atividades de Investimento  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 3840                            7.188400e+07
# 3841                            2.098000e+06
# 3842                            6.251000e+06
# 3843                            5.993617e+09
# 3844                            4.825556e+09
#
#       Reservas Restritas Separadas do Lucro  TOTAL DE ATIVOS  \
# 0                                 2957664.0     6.075340e+07
# 1                                 2957664.0     6.075340e+07
# 2                                 4729678.0     7.304626e+07
# 3                                 5450104.0     9.103184e+07
# 4                                 6378203.0     1.113401e+08
# ...                                     ...              ...
# 3840                              7931000.0     2.140257e+10
# 3841                              7931000.0     3.542642e+10
# 3842                            100624000.0     1.177445e+11
# 3843                            145280000.0     1.422292e+11
# 3844                            145280000.0     1.187847e+11
#
#       TOTAL DO PASSIVO E PATRIMÔNICO LÍQUIDO  \
# 0                               6.075340e+07
# 1                               6.075340e+07
# 2                               7.304626e+07
# 3                               9.103184e+07
# 4                               1.113401e+08
# ...                                      ...
# 3840                            2.140257e+10
# 3841                            3.542642e+10
# 3842                            1.177445e+11
# 3843                            1.422292e+11
# 3844                            1.187847e+11
#
#       Valores de Caixa no Início do Período  Variação nas Dívidas Financeiras  \
# 0                                       NaN                               NaN
# 1                                       NaN                               NaN
# 2                                       NaN                               NaN
# 3                                       NaN                               NaN
# 4                                       NaN                               NaN
# ...                                     ...                               ...
# 3840                           8.231210e+08                     -4.692610e+08
# 3841                           7.099090e+08                      5.478490e+08
# 3842                           3.205222e+09                      2.920434e+09
# 3843                           5.456515e+09                     -1.093341e+10
# 3844                           2.779085e+09                     -2.194924e+09
#
#       Variação no Caixa e Equivalentes  Vendas Domésticas  \
# 0                                  NaN         87260709.0
# 1                                  NaN         87260709.0
# 2                                  NaN        104427004.0
# 3                                  NaN        132355741.0
# 4                                  NaN        162911678.0
# ...                                ...                ...
# 3840                      -113212000.0                0.0
# 3841                       451735000.0                0.0
# 3842                       574086000.0                0.0
# 3843                      -532490000.0                0.0
# 3844                      -705924000.0                0.0
#
#       Vendas Internacionais
# 0                 4865016.0
# 1                 4865016.0
# 2                 5399918.0
# 3                 6157158.0
# 4                 7611179.0
# ...                     ...
# 3840                    0.0
# 3841                    0.0
# 3842                    0.0
# 3843                    0.0
# 3844                    0.0
#
# [3845 rows x 85 columns]

# %%
df_clean.isnull().sum()
# Out:
# CompanyCode                                 0
# Ano                                         0
#   Investimentos em Capital Fixo          1724
# (Subtotal)                                  2
# Ajustes:                                 1724
#                                          ...
# Valores de Caixa no Início do Período    1724
# Variação nas Dívidas Financeiras         1724
# Variação no Caixa e Equivalentes         1724
# Vendas Domésticas                           2
# Vendas Internacionais                       2
# Length: 85, dtype: int64

# %%
df_clean['Lucro Operacional Antes das Mudanças no Capital de Giro (+)'].isnull().sum()
# Out:
# np.int64(1724)

# %%
df_clean['LUCRO OPERACIONAL (PREJUÍZO)'].isnull().sum()
# Out:
# np.int64(2)

# %%
df_clean['Amortização e Quotas de Exaustão'].isnull().sum()
# Out:
# np.int64(1724)

# %%
df_clean['Lucro Operacional Antes das Mudanças no Capital de Giro (+)'].isnull().sum()
# Out:
# np.int64(1724)

# %%
# Build do EBITDA ...
''' Colunas EBITDA pode ser construido com EBIT + Depreciação/Amortização
    1. Se EBITDA disponível, usar direto
    2. Se não, usar EBIT + Amortização
    3. Se ainda não disponível, aproximar como EBIT + 5% dos ativos totais
'''

df_clean.rename(columns={
    "Lucro Operacional Antes das Mudanças no Capital de Giro (+)": "EBITDA",
    "LUCRO OPERACIONAL (PREJUÍZO)": "EBIT",
    "Amortização e Quotas de Exaustão": "Amortization"
}, inplace=True)

df_clean["EBITDA_Final"] = df_clean["EBITDA"]

# Fill with EBIT + Amortization where available
df_clean.loc[df_clean["EBITDA_Final"].isna() & df_clean["Amortization"].notna(),
       "EBITDA_Final"] = df_clean["EBIT"] + df_clean["Amortization"]

# If still missing, approximate using 5% of total assets
df_clean.loc[df_clean["EBITDA_Final"].isna(), "EBITDA_Final"] = (
    df_clean.loc[df_clean["EBITDA_Final"].isna(), "EBIT"] + 0.05 * df_clean.loc[df_clean["EBITDA_Final"].isna(), "TOTAL DE ATIVOS"]
)

# FLAG pra rastrear a origem do EBITDA
df_clean["EBITDA_Source"] = np.select(
    [
        df_clean["EBITDA"].notna(),         
        df_clean["Amortization"].notna()    
    ],
    [
        "Reported",                      
        "Reconstructed"                    
    ],
    default="Estimated"                     
).astype("object")

# %%
df_clean
# Out:
#      CompanyCode   Ano    Investimentos em Capital Fixo    (Subtotal)  \
# 0           ADEL  2008                              NaN  2.701881e+07
# 1           ADEL  2009                              NaN  2.701881e+07
# 2           ADEL  2010                              NaN  3.387275e+07
# 3           ADEL  2011                              NaN  4.391425e+07
# 4           ADEL  2012                              NaN  5.461005e+07
# ...          ...   ...                              ...           ...
# 3840       ZOREN  2020                    -1.881500e+08  6.037722e+09
# 3841       ZOREN  2021                    -3.353620e+08  7.986534e+09
# 3842       ZOREN  2022                    -9.923150e+08  3.006555e+10
# 3843       ZOREN  2023                    -1.219082e+09  2.698698e+10
# 3844       ZOREN  2024                    -1.202219e+09  1.677384e+10
#
#           Ajustes:  Amortization  Ativo Fiscal Diferido  Ativos Circulantes  \
# 0              NaN           NaN           0.000000e+00        4.558265e+07
# 1              NaN           NaN           0.000000e+00        4.558265e+07
# 2              NaN           NaN           0.000000e+00        5.862145e+07
# 3              NaN           NaN           1.139980e+05        7.555084e+07
# 4              NaN           NaN           3.464180e+05        9.348416e+07
# ...            ...           ...                    ...                 ...
# 3840  1.872685e+09  6.032930e+08           4.888430e+08        4.047594e+09
# 3841  2.968941e+09  6.905980e+08           6.717470e+08        6.471306e+09
# 3842 -7.099029e+09  3.668976e+09           1.700569e+09        2.259070e+10
# 3843 -1.209898e+10  6.194368e+09           6.855687e+09        2.862619e+10
# 3844 -7.936120e+08  4.827761e+09           1.057653e+10        1.341005e+10
#
#       Ativos Imobilizados  Ativos Intangíveis  ...  \
# 0            1.471694e+07        5.988400e+04  ...
# 1            1.471694e+07        5.988400e+04  ...
# 2            1.386170e+07        1.258040e+05  ...
# 3            1.476274e+07        1.452930e+05  ...
# 4            1.613625e+07        1.755500e+05  ...
# ...                   ...                 ...  ...
# 3840         1.061079e+10        1.506887e+09  ...
# 3841         1.878782e+10        1.501186e+09  ...
# 3842         5.698022e+10        8.819497e+09  ...
# 3843         5.836801e+10        1.106112e+10  ...
# 3844         5.496624e+10        1.048758e+10  ...
#
#       Reservas Restritas Separadas do Lucro  TOTAL DE ATIVOS  \
# 0                                 2957664.0     6.075340e+07
# 1                                 2957664.0     6.075340e+07
# 2                                 4729678.0     7.304626e+07
# 3                                 5450104.0     9.103184e+07
# 4                                 6378203.0     1.113401e+08
# ...                                     ...              ...
# 3840                              7931000.0     2.140257e+10
# 3841                              7931000.0     3.542642e+10
# 3842                            100624000.0     1.177445e+11
# 3843                            145280000.0     1.422292e+11
# 3844                            145280000.0     1.187847e+11
#
#       TOTAL DO PASSIVO E PATRIMÔNICO LÍQUIDO  \
# 0                               6.075340e+07
# 1                               6.075340e+07
# 2                               7.304626e+07
# 3                               9.103184e+07
# 4                               1.113401e+08
# ...                                      ...
# 3840                            2.140257e+10
# 3841                            3.542642e+10
# 3842                            1.177445e+11
# 3843                            1.422292e+11
# 3844                            1.187847e+11
#
#       Valores de Caixa no Início do Período  Variação nas Dívidas Financeiras  \
# 0                                       NaN                               NaN
# 1                                       NaN                               NaN
# 2                                       NaN                               NaN
# 3                                       NaN                               NaN
# 4                                       NaN                               NaN
# ...                                     ...                               ...
# 3840                           8.231210e+08                     -4.692610e+08
# 3841                           7.099090e+08                      5.478490e+08
# 3842                           3.205222e+09                      2.920434e+09
# 3843                           5.456515e+09                     -1.093341e+10
# 3844                           2.779085e+09                     -2.194924e+09
#
#       Variação no Caixa e Equivalentes  Vendas Domésticas  \
# 0                                  NaN         87260709.0
# 1                                  NaN         87260709.0
# 2                                  NaN        104427004.0
# 3                                  NaN        132355741.0
# 4                                  NaN        162911678.0
# ...                                ...                ...
# 3840                      -113212000.0                0.0
# 3841                       451735000.0                0.0
# 3842                       574086000.0                0.0
# 3843                      -532490000.0                0.0
# 3844                      -705924000.0                0.0
#
#       Vendas Internacionais  EBITDA_Final  EBITDA_Source
# 0                 4865016.0  2.381818e+07      Estimated
# 1                 4865016.0  2.381818e+07      Estimated
# 2                 5399918.0  2.659145e+07      Estimated
# 3                 6157158.0  3.328506e+07      Estimated
# 4                 7611179.0  4.093322e+07      Estimated
# ...                     ...           ...            ...
# 3840                    0.0  1.910892e+09       Reported
# 3841                    0.0  2.809507e+09       Reported
# 3842                    0.0  2.409707e+09       Reported
# 3843                    0.0  3.762464e+09       Reported
# 3844                    0.0 -3.158172e+09       Reported
#
# [3845 rows x 87 columns]

# %%
# LIMPEZA DOS NOMES DAS COLUNAS
def clean_col_name(col_name):
    # Remove leading/trailing spaces
    name = col_name.strip()
    # Replace special characters and spaces with underscore
    name = name.replace(' ', '_').replace('(-)', '').replace('(PREJUÍZO)', '').replace('/', '_')
    # Remove other special characters
    name = ''.join(e for e in name if e.isalnum() or e == '_')
    # Convert to lowercase
    name = name.lower()
    # Remove any trailing underscores
    name = name.strip('_')
    return name

# Apply the cleaning function to all columns
df_clean.columns = [clean_col_name(col) for col in df_clean.columns]

# %%
colunas_para_remover = [
    'investimentos_em_capital_fixo', 'subtotal', 'ajustes', 'ativos_imobilizados',
    'ativos_intangíveis', 'ativos_não_circulantes', 'caixa_no_final_do_período',
    'capital_social_integralizado', 'contas_a_pagar', 'despesas_financeiras_não_operacionais',
    'despesas_gerais_e_administrativas', 'despesas_de_amortização',
    'despesas_de_atividades_de_investimento', 'despesas_de_marketing_vendas_e_distribuição',
    'fluxo_de_caixa_livre', 'investimentos_financeiros', 'lucro__do_período',
    'lucro_bruto', 'lucro_prejuízo_líquido_do_período_das_operações_continuadas',
    'lucro_bruto_prejuízo_de_atividades_comerciais', 'outras_despesas_operacionais',
    'outras_dívidas', 'outras_receitas_operacionais',
    'outras_receitas_e_despesas_antes_do_imposto', 'outros_ativos_não_circulantes',
    'outros_itens_do_patrimônio_líquido', 'outros_passivos_circulantes',
    'outros_recebíveis', 'participações_da_controladora', 'passivo_fiscal_diferido',
    'passivos_não_circulantes', 'patrimônio_líquido_atribuível_aos_acionistas_da_controladora',
    'provisões_de_longo_prazo', 'provisões_para_dívidas',
    'receita_despesa_de_imposto_diferido',
    'receita_despesa_de_imposto_das_operações_continuadas',
    'receita_despesa_de_imposto_do_período', 'receitas_financeiras_não_operacionais',
    'reservas_restritas_separadas_do_lucro', 'total_do_passivo_e_patrimônico_líquido',
    'vendas_domésticas', 'vendas_internacionais', 
    'Ativo Fiscal Diferido',
    'Aumento/Diminuição Líquido de Caixa e Equivalentes de Caixa Antes do Efeito das Diferenças de Conversão de Moeda Estrangeira',
    'Caixa Gerado por Atividades Principais (+)',
    'Efeito das Diferenças de Conversão de Moeda Estrangeira sobre o Caixa e Equivalentes de Caixa',
    'Fluxo de Caixa Líquido das Atividades Operacionais',                                                                              
    'Fluxo de Caixa das Atividades de Financiamento',                                                                                  
    'Fluxo de Caixa das Atividades de Investimento',                                                                                   
    'Fluxo de Caixa de Outras Atividades Operacionais',                                                                                
    'Fluxo de Caixa de Outras Atividades de Financiamento',                                                                            
    'Fluxo de Caixa de Outras Atividades de Investimento',                                                                             
    'Indenização por Antiguidade',
    'Lucro Antes dos Ajustes',
    'Mudança nas Provisões',                                                                                                           
    'Mudanças no Capital de Giro',
    'Outras Receitas/Despesas',
    'Pagamento de Dividendos',
    'Posição Cambial Líquida (Incluindo Hedge)',                                                                                     
    'Posição Líquida (Ativo/Passivo) Monetária em Moeda Estrangeira',
    'Receitas de Atividades de Investimento',
    'Valores de Caixa no Início do Período',                                                                                           
    'Variação nas Dívidas Financeiras',                                                                                                
    'Variação no Caixa e Equivalentes',
    'EBITDA', 'EBITDA_Source'
]

# Drop columns safely, ignoring any that don’t exist
df_cleaner = df_clean.drop(columns=colunas_para_remover, errors='ignore')

print(f"Colunas antes do drop: {df_clean.shape[1]}")
print(f"Colunas após o drop: {df_cleaner.shape[1]}")

# Show remaining columns
print("\nColunas restantes para o modelo:")
print(df_cleaner.columns.to_list())
# Out:
# Colunas antes do drop: 87
# Colunas após o drop: 45
#
# Colunas restantes para o modelo:
# ['companycode', 'ano', 'amortization', 'ativo_fiscal_diferido', 'ativos_circulantes', 'aumento_diminuição_líquido_de_caixa_e_equivalentes_de_caixa_antes_do_efeito_das_diferenças_de_conversão_de_moeda_estrangeira', 'caixa_gerado_por_atividades_principais', 'caixa_e_equivalentes_de_caixa', 'contas_a_receber', 'custo_dos_produtos_serviços_vendidos', 'despesas_financeiras', 'dívidas_financeiras', 'efeito_das_diferenças_de_conversão_de_moeda_estrangeira_sobre_o_caixa_e_equivalentes_de_caixa', 'estoques', 'fluxo_de_caixa_líquido_das_atividades_operacionais', 'fluxo_de_caixa_das_atividades_de_financiamento', 'fluxo_de_caixa_das_atividades_de_investimento', 'fluxo_de_caixa_de_outras_atividades_operacionais', 'fluxo_de_caixa_de_outras_atividades_de_financiamento', 'fluxo_de_caixa_de_outras_atividades_de_investimento', 'indenização_por_antiguidade', 'ebit', 'lucro_antes_dos_ajustes', 'ebitda', 'lucro_prejuízo_líquido_do_período', 'lucro_prejuízo_operacional_líquido', 'lucros_prejuízos_acumulados', 'mudança_nas_provisões', 'mudanças_no_capital_de_giro', 'outras_receitas_despesas', 'outros_ativos_circulantes', 'pagamento_de_dividendos', 'passivos_circulantes', 'patrimônio_líquido', 'posição_cambial_líquida', 'posição_cambial_líquida_incluindo_hedge', 'posição_líquida_ativo_passivo_monetária_em_moeda_estrangeira', 'receita_de_vendas', 'receitas_de_atividades_de_investimento', 'total_de_ativos', 'valores_de_caixa_no_início_do_período', 'variação_nas_dívidas_financeiras', 'variação_no_caixa_e_equivalentes', 'ebitda_final', 'ebitda_source']

# %%
ebitda_source

# %%
# drop de mais algumas colunas que nao vamos usar ...
df_cleaner=df_cleaner.drop(columns=[
                                ],axis=1)

# %%
print(df_cleaner.isnull().sum().to_string())
# Out:
# companycode                                                                                                                        0
# ano                                                                                                                                0
# amortization                                                                                                                    1724
# ativo_fiscal_diferido                                                                                                              2
# ativos_circulantes                                                                                                                 2
# aumento_diminuição_líquido_de_caixa_e_equivalentes_de_caixa_antes_do_efeito_das_diferenças_de_conversão_de_moeda_estrangeira    1724
# caixa_gerado_por_atividades_principais                                                                                          1724
# caixa_e_equivalentes_de_caixa                                                                                                      2
# contas_a_receber                                                                                                                   2
# custo_dos_produtos_serviços_vendidos                                                                                               2
# despesas_financeiras                                                                                                               2
# dívidas_financeiras                                                                                                                2
# efeito_das_diferenças_de_conversão_de_moeda_estrangeira_sobre_o_caixa_e_equivalentes_de_caixa                                   1724
# estoques                                                                                                                           2
# fluxo_de_caixa_líquido_das_atividades_operacionais                                                                              1724
# fluxo_de_caixa_das_atividades_de_financiamento                                                                                  1724
# fluxo_de_caixa_das_atividades_de_investimento                                                                                   1724
# fluxo_de_caixa_de_outras_atividades_operacionais                                                                                1724
# fluxo_de_caixa_de_outras_atividades_de_financiamento                                                                            1724
# fluxo_de_caixa_de_outras_atividades_de_investimento                                                                             1724
# indenização_por_antiguidade                                                                                                        2
# ebit                                                                                                                               2
# lucro_antes_dos_ajustes                                                                                                         1724
# ebitda                                                                                                                          1724
# lucro_prejuízo_líquido_do_período                                                                                                  2
# lucro_prejuízo_operacional_líquido                                                                                                 2
# lucros_prejuízos_acumulados                                                                                                        2
# mudança_nas_provisões                                                                                                           1724
# mudanças_no_capital_de_giro                                                                                                     1724
# outras_receitas_despesas                                                                                                        1724
# outros_ativos_circulantes                                                                                                          2
# pagamento_de_dividendos                                                                                                         1724
# passivos_circulantes                                                                                                               2
# patrimônio_líquido                                                                                                                 2
# posição_cambial_líquida                                                                                                            2
# posição_cambial_líquida_incluindo_hedge                                                                                         1123
# posição_líquida_ativo_passivo_monetária_em_moeda_estrangeira                                                                    1123
# receita_de_vendas                                                                                                                  2
# receitas_de_atividades_de_investimento                                                                                          1724
# total_de_ativos                                                                                                                    2
# valores_de_caixa_no_início_do_período                                                                                           1724
# variação_nas_dívidas_financeiras                                                                                                1724
# variação_no_caixa_e_equivalentes                                                                                                1724
# ebitda_final                                                                                                                       2
# ebitda_source                                                                                                                      0

# %%
# fill NA com mediana das colunas numericas que ainda tem NA
df_cleaner = df_cleaner.fillna(df_clean.median(numeric_only=True))

# %%
df_cleaner
# Out:
#      companycode   ano  amortization  ativo_fiscal_diferido  \
# 0           ADEL  2008  2.157076e+07           0.000000e+00
# 1           ADEL  2009  2.157076e+07           0.000000e+00
# 2           ADEL  2010  2.157076e+07           0.000000e+00
# 3           ADEL  2011  2.157076e+07           1.139980e+05
# 4           ADEL  2012  2.157076e+07           3.464180e+05
# ...          ...   ...           ...                    ...
# 3840       ZOREN  2020  6.032930e+08           4.888430e+08
# 3841       ZOREN  2021  6.905980e+08           6.717470e+08
# 3842       ZOREN  2022  3.668976e+09           1.700569e+09
# 3843       ZOREN  2023  6.194368e+09           6.855687e+09
# 3844       ZOREN  2024  4.827761e+09           1.057653e+10
#
#       ativos_circulantes  \
# 0           4.558265e+07
# 1           4.558265e+07
# 2           5.862145e+07
# 3           7.555084e+07
# 4           9.348416e+07
# ...                  ...
# 3840        4.047594e+09
# 3841        6.471306e+09
# 3842        2.259070e+10
# 3843        2.862619e+10
# 3844        1.341005e+10
#
#       aumento_diminuição_líquido_de_caixa_e_equivalentes_de_caixa_antes_do_efeito_das_diferenças_de_conversão_de_moeda_estrangeira  \
# 0                                             2612322.0
# 1                                             2612322.0
# 2                                             2612322.0
# 3                                             2612322.0
# 4                                             2612322.0
# ...                                                 ...
# 3840                                         17074000.0
# 3841                                        569065000.0
# 3842                                        659141000.0
# 3843                                       -320833000.0
# 3844                                       -622439000.0
#
#       caixa_gerado_por_atividades_principais  caixa_e_equivalentes_de_caixa  \
# 0                               5.328500e+07                   1.227897e+07
# 1                               5.328500e+07                   1.227897e+07
# 2                               5.328500e+07                   2.335695e+07
# 3                               5.328500e+07                   3.236535e+07
# 4                               5.328500e+07                   9.840553e+06
# ...                                      ...                            ...
# 3840                            2.018797e+09                   7.283140e+08
# 3841                            2.158161e+09                   1.171070e+09
# 3842                            3.523400e+09                   3.798939e+09
# 3843                            1.751314e+10                   2.791942e+09
# 3844                            7.230694e+09                   1.541918e+09
#
#       contas_a_receber  custo_dos_produtos_serviços_vendidos  ...  \
# 0         1.732210e+06                         -3.696912e+07  ...
# 1         1.732210e+06                         -3.696912e+07  ...
# 2         2.596836e+06                         -4.505084e+07  ...
# 3         4.467178e+06                         -5.633102e+07  ...
# 4         8.249453e+06                         -6.899659e+07  ...
# ...                ...                                   ...  ...
# 3840      7.336395e+08                         -7.062390e+09  ...
# 3841      1.449004e+09                         -9.771696e+09  ...
# 3842      5.977620e+09                         -3.314787e+10  ...
# 3843      4.591502e+09                         -3.395732e+10  ...
# 3844      3.510718e+09                         -2.594755e+10  ...
#
#       posição_cambial_líquida_incluindo_hedge  \
# 0                               -3.069320e+06
# 1                               -3.069320e+06
# 2                               -3.069320e+06
# 3                               -3.069320e+06
# 4                               -3.069320e+06
# ...                                       ...
# 3840                            -8.527695e+09
# 3841                            -1.496387e+10
# 3842                            -2.909134e+10
# 3843                            -2.947374e+10
# 3844                            -2.796079e+10
#
#       posição_líquida_ativo_passivo_monetária_em_moeda_estrangeira  \
# 0                                         -5.493300e+06
# 1                                         -5.493300e+06
# 2                                         -5.493300e+06
# 3                                         -5.493300e+06
# 4                                         -5.493300e+06
# ...                                                 ...
# 3840                                      -8.397268e+09
# 3841                                      -1.525123e+10
# 3842                                      -2.940193e+10
# 3843                                      -2.965550e+10
# 3844                                      -2.802380e+10
#
#       receita_de_vendas  receitas_de_atividades_de_investimento  \
# 0          7.478781e+07                            3.446370e+06
# 1          7.478781e+07                            3.446370e+06
# 2          8.778961e+07                            3.446370e+06
# 3          1.113844e+08                            3.446370e+06
# 4          1.361230e+08                            3.446370e+06
# ...                 ...                                     ...
# 3840       8.579113e+09                            7.188400e+07
# 3841       1.163481e+10                            2.098000e+06
# 3842       3.880610e+10                            6.251000e+06
# 3843       3.938931e+10                            5.993617e+09
# 3844       2.965760e+10                            4.825556e+09
#
#       total_de_ativos  valores_de_caixa_no_início_do_período  \
# 0        6.075340e+07                           5.570042e+07
# 1        6.075340e+07                           5.570042e+07
# 2        7.304626e+07                           5.570042e+07
# 3        9.103184e+07                           5.570042e+07
# 4        1.113401e+08                           5.570042e+07
# ...               ...                                    ...
# 3840     2.140257e+10                           8.231210e+08
# 3841     3.542642e+10                           7.099090e+08
# 3842     1.177445e+11                           3.205222e+09
# 3843     1.422292e+11                           5.456515e+09
# 3844     1.187847e+11                           2.779085e+09
#
#       variação_nas_dívidas_financeiras  variação_no_caixa_e_equivalentes  \
# 0                         0.000000e+00                         2612322.0
# 1                         0.000000e+00                         2612322.0
# 2                         0.000000e+00                         2612322.0
# 3                         0.000000e+00                         2612322.0
# 4                         0.000000e+00                         2612322.0
# ...                                ...                               ...
# 3840                     -4.692610e+08                      -113212000.0
# 3841                      5.478490e+08                       451735000.0
# 3842                      2.920434e+09                       574086000.0
# 3843                     -1.093341e+10                      -532490000.0
# 3844                     -2.194924e+09                      -705924000.0
#
#       ebitda_final  ebitda_source
# 0     2.381818e+07      Estimated
# 1     2.381818e+07      Estimated
# 2     2.659145e+07      Estimated
# 3     3.328506e+07      Estimated
# 4     4.093322e+07      Estimated
# ...            ...            ...
# 3840  1.910892e+09       Reported
# 3841  2.809507e+09       Reported
# 3842  2.409707e+09       Reported
# 3843  3.762464e+09       Reported
# 3844 -3.158172e+09       Reported
#
# [3845 rows x 45 columns]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3845 entries, 0 to 3844
# Data columns (total 87 columns):
#  #   Column                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                        --------------  -----
#  0   companycode                                                                                                                   3845 non-null   object
#  1   ano                                                                                                                           3845 non-null   int64
#  2   investimentos_em_capital_fixo                                                                                                 2121 non-null   float64
#  3   subtotal                                                                                                                      3843 non-null   float64
#  4   ajustes                                                                                                                       2121 non-null   float64
#  5   amortization                                                                                                                  2121 non-null   float64
#  6   ativo_fiscal_diferido                                                                                                         3843 non-null   float64
#  7   ativos_circulantes                                                                                                            3843 non-null   float64
#  8   ativos_imobilizados                                                                                                           3843 non-null   float64
#  9   ativos_intangíveis                                                                                                            3843 non-null   float64
#  10  ativos_não_circulantes                                                                                                        3843 non-null   float64
#  11  aumento_diminuição_líquido_de_caixa_e_equivalentes_de_caixa_antes_do_efeito_das_diferenças_de_conversão_de_moeda_estrangeira  2121 non-null   float64
#  12  caixa_gerado_por_atividades_principais                                                                                        2121 non-null   float64
#  13  caixa_e_equivalentes_de_caixa                                                                                                 3843 non-null   float64
#  14  caixa_no_final_do_período                                                                                                     2121 non-null   float64
#  15  capital_social_integralizado                                                                                                  3843 non-null   float64
#  16  contas_a_pagar                                                                                                                3843 non-null   float64
#  17  contas_a_receber                                                                                                              3843 non-null   float64
#  18  custo_dos_produtos_serviços_vendidos                                                                                          3843 non-null   float64
#  19  despesas_financeiras                                                                                                          3843 non-null   float64
#  20  despesas_financeiras_não_operacionais                                                                                         3843 non-null   float64
#  21  despesas_gerais_e_administrativas                                                                                             3843 non-null   float64
#  22  despesas_de_amortização                                                                                                       3843 non-null   float64
#  23  despesas_de_atividades_de_investimento                                                                                        2121 non-null   float64
#  24  despesas_de_marketing_vendas_e_distribuição                                                                                   3843 non-null   float64
#  25  dívidas_financeiras                                                                                                           3843 non-null   float64
#  26  efeito_das_diferenças_de_conversão_de_moeda_estrangeira_sobre_o_caixa_e_equivalentes_de_caixa                                 2121 non-null   float64
#  27  estoques                                                                                                                      3843 non-null   float64
#  28  fluxo_de_caixa_livre                                                                                                          2121 non-null   float64
#  29  fluxo_de_caixa_líquido_das_atividades_operacionais                                                                            2121 non-null   float64
#  30  fluxo_de_caixa_das_atividades_de_financiamento                                                                                2121 non-null   float64
#  31  fluxo_de_caixa_das_atividades_de_investimento                                                                                 2121 non-null   float64
#  32  fluxo_de_caixa_de_outras_atividades_operacionais                                                                              2121 non-null   float64
#  33  fluxo_de_caixa_de_outras_atividades_de_financiamento                                                                          2121 non-null   float64
#  34  fluxo_de_caixa_de_outras_atividades_de_investimento                                                                           2121 non-null   float64
#  35  indenização_por_antiguidade                                                                                                   3843 non-null   float64
#  36  investimentos_financeiros                                                                                                     3843 non-null   float64
#  37  lucro__do_período                                                                                                             3843 non-null   float64
#  38  lucro_bruto                                                                                                                   3843 non-null   float64
#  39  ebit                                                                                                                          3843 non-null   float64
#  40  lucro_prejuízo_líquido_do_período_das_operações_continuadas                                                                   3843 non-null   float64
#  41  lucro_antes_dos_ajustes                                                                                                       2121 non-null   float64
#  42  lucro_bruto_prejuízo_de_atividades_comerciais                                                                                 3843 non-null   float64
#  43  ebitda                                                                                                                        2121 non-null   float64
#  44  lucro_prejuízo_líquido_do_período                                                                                             3843 non-null   float64
#  45  lucro_prejuízo_operacional_líquido                                                                                            3843 non-null   float64
#  46  lucros_prejuízos_acumulados                                                                                                   3843 non-null   float64
#  47  mudança_nas_provisões                                                                                                         2121 non-null   float64
#  48  mudanças_no_capital_de_giro                                                                                                   2121 non-null   float64
#  49  outras_despesas_operacionais                                                                                                  3843 non-null   float64
#  50  outras_dívidas                                                                                                                3843 non-null   float64
#  51  outras_receitas_operacionais                                                                                                  3843 non-null   float64
#  52  outras_receitas_e_despesas_antes_do_imposto                                                                                   3843 non-null   float64
#  53  outras_receitas_despesas                                                                                                      2121 non-null   float64
#  54  outros_ativos_circulantes                                                                                                     3843 non-null   float64
#  55  outros_ativos_não_circulantes                                                                                                 3843 non-null   float64
#  56  outros_itens_do_patrimônio_líquido                                                                                            3843 non-null   float64
#  57  outros_passivos_circulantes                                                                                                   3843 non-null   float64
#  58  outros_recebíveis                                                                                                             3843 non-null   float64
#  59  pagamento_de_dividendos                                                                                                       2121 non-null   float64
#  60  participações_da_controladora                                                                                                 3843 non-null   float64
#  61  passivo_fiscal_diferido                                                                                                       3843 non-null   float64
#  62  passivos_circulantes                                                                                                          3843 non-null   float64
#  63  passivos_não_circulantes                                                                                                      3843 non-null   float64
#  64  patrimônio_líquido                                                                                                            3843 non-null   float64
#  65  patrimônio_líquido_atribuível_aos_acionistas_da_controladora                                                                  3843 non-null   float64
#  66  posição_cambial_líquida                                                                                                       3843 non-null   float64
#  67  posição_cambial_líquida_incluindo_hedge                                                                                       2722 non-null   float64
#  68  posição_líquida_ativo_passivo_monetária_em_moeda_estrangeira                                                                  2722 non-null   float64
#  69  provisões_de_longo_prazo                                                                                                      3843 non-null   float64
#  70  provisões_para_dívidas                                                                                                        3843 non-null   float64
#  71  receita_despesa_de_imposto_diferido                                                                                           3843 non-null   float64
#  72  receita_despesa_de_imposto_das_operações_continuadas                                                                          3843 non-null   float64
#  73  receita_despesa_de_imposto_do_período                                                                                         3843 non-null   float64
#  74  receita_de_vendas                                                                                                             3843 non-null   float64
#  75  receitas_financeiras_não_operacionais                                                                                         3843 non-null   float64
#  76  receitas_de_atividades_de_investimento                                                                                        2121 non-null   float64
#  77  reservas_restritas_separadas_do_lucro                                                                                         3843 non-null   float64
#  78  total_de_ativos                                                                                                               3843 non-null   float64
#  79  total_do_passivo_e_patrimônico_líquido                                                                                        3843 non-null   float64
#  80  valores_de_caixa_no_início_do_período                                                                                         2121 non-null   float64
#  81  variação_nas_dívidas_financeiras                                                                                              2121 non-null   float64
#  82  variação_no_caixa_e_equivalentes                                                                                              2121 non-null   float64
#  83  vendas_domésticas                                                                                                             3843 non-null   float64
#  84  vendas_internacionais                                                                                                         3843 non-null   float64
#  85  ebitda_final                                                                                                                  3843 non-null   float64
#  86  ebitda_source                                                                                                                 3845 non-null   object
# dtypes: float64(84), int64(1), object(2)
# memory usage: 2.6+ MB

# %%
df_cleaner.columns
# Out:
# Index(['companycode', 'ano', 'amortization', 'ativo_fiscal_diferido',
#        'ativos_circulantes',
#        'aumento_diminuição_líquido_de_caixa_e_equivalentes_de_caixa_antes_do_efeito_das_diferenças_de_conversão_de_moeda_estrangeira',
#        'caixa_gerado_por_atividades_principais',
#        'caixa_e_equivalentes_de_caixa', 'contas_a_receber',
#        'custo_dos_produtos_serviços_vendidos', 'despesas_financeiras',
#        'dívidas_financeiras',
#        'efeito_das_diferenças_de_conversão_de_moeda_estrangeira_sobre_o_caixa_e_equivalentes_de_caixa',
#        'estoques', 'fluxo_de_caixa_líquido_das_atividades_operacionais',
#        'fluxo_de_caixa_das_atividades_de_financiamento',
#        'fluxo_de_caixa_das_atividades_de_investimento',
#        'fluxo_de_caixa_de_outras_atividades_operacionais',
#        'fluxo_de_caixa_de_outras_atividades_de_financiamento',
#        'fluxo_de_caixa_de_outras_atividades_de_investimento',
#        'indenização_por_antiguidade', 'ebit', 'lucro_antes_dos_ajustes',
#        'ebitda', 'lucro_prejuízo_líquido_do_período',
#        'lucro_prejuízo_operacional_líquido', 'lucros_prejuízos_acumulados',
#        'mudança_nas_provisões', 'mudanças_no_capital_de_giro',
#        'outras_receitas_despesas', 'outros_ativos_circulantes',
#        'pagamento_de_dividendos', 'passivos_circulantes', 'patrimônio_líquido',
#        'posição_cambial_líquida', 'posição_cambial_líquida_incluindo_hedge',
#        'posição_líquida_ativo_passivo_monetária_em_moeda_estrangeira',
#        'receita_de_vendas', 'receitas_de_atividades_de_investimento',
#        'total_de_ativos', 'valores_de_caixa_no_início_do_período',
#        'variação_nas_dívidas_financeiras', 'variação_no_caixa_e_equivalentes',
#        'ebitda_final', 'ebitda_source'],
#       dtype='object')

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# -----

# %%
df_clean = df_clean.rename(columns={
    'lucro_prejuizo_liquido_do_periodo_das_operações_continuadas': 'lucro_liquido_op_continuas',
    'lucro_bruto_prejuizo': 'lucro_bruto',
    'custo_dos_produtos_serviços_vendidos': 'cogs', 
    'lucro_prejuizo_do_periodo': 'lucro_periodo'
})

# %%
from financial_ratios import create_financial_ratios

df_with_ratios = create_financial_ratios(df_clean)
# Out:
# c:\Users\gregorio\TCC-CD-USP\financial_ratios.py:59: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   data['sales_growth'] = data.groupby('companycode')['receita_de_vendas'].pct_change()
# c:\Users\gregorio\TCC-CD-USP\financial_ratios.py:60: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   data['asset_growth'] = data.groupby('companycode')['total_de_ativos'].pct_change()
# c:\Users\gregorio\TCC-CD-USP\financial_ratios.py:61: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   data['net_income_growth'] = data.groupby('companycode')['lucro_prejuízo_líquido_do_período'].pct_change()

# %%
df_with_ratios
# Out:
#      companycode   ano  investimentos_em_capital_fixo      subtotal  \
# 0           ADEL  2008                            NaN  2.701881e+07
# 1           ADEL  2009                            NaN  2.701881e+07
# 2           ADEL  2010                            NaN  3.387275e+07
# 3           ADEL  2011                            NaN  4.391425e+07
# 4           ADEL  2012                            NaN  5.461005e+07
# ...          ...   ...                            ...           ...
# 3840       ZOREN  2020                  -1.881500e+08  6.037722e+09
# 3841       ZOREN  2021                  -3.353620e+08  7.986534e+09
# 3842       ZOREN  2022                  -9.923150e+08  3.006555e+10
# 3843       ZOREN  2023                  -1.219082e+09  2.698698e+10
# 3844       ZOREN  2024                  -1.202219e+09  1.677384e+10
#
#            ajustes  amortization  ativo_fiscal_diferido  ativos_circulantes  \
# 0              NaN           NaN           0.000000e+00        4.558265e+07
# 1              NaN           NaN           0.000000e+00        4.558265e+07
# 2              NaN           NaN           0.000000e+00        5.862145e+07
# 3              NaN           NaN           1.139980e+05        7.555084e+07
# 4              NaN           NaN           3.464180e+05        9.348416e+07
# ...            ...           ...                    ...                 ...
# 3840  1.872685e+09  6.032930e+08           4.888430e+08        4.047594e+09
# 3841  2.968941e+09  6.905980e+08           6.717470e+08        6.471306e+09
# 3842 -7.099029e+09  3.668976e+09           1.700569e+09        2.259070e+10
# 3843 -1.209898e+10  6.194368e+09           6.855687e+09        2.862619e+10
# 3844 -7.936120e+08  4.827761e+09           1.057653e+10        1.341005e+10
#
#       ativos_imobilizados  ativos_intangíveis  ...  operating_margin  \
# 0            1.471694e+07        5.988400e+04  ...          0.263879
# 1            1.471694e+07        5.988400e+04  ...          0.263879
# 2            1.386170e+07        1.258040e+05  ...          0.264218
# 3            1.476274e+07        1.452930e+05  ...          0.270666
# 4            1.613625e+07        1.755500e+05  ...          0.273883
# ...                   ...                 ...  ...               ...
# 3840         1.061079e+10        1.506887e+09  ...          0.141477
# 3841         1.878782e+10        1.501186e+09  ...          0.125758
# 3842         5.698022e+10        8.819497e+09  ...          0.113481
# 3843         5.836801e+10        1.106112e+10  ...          0.080205
# 3844         5.496624e+10        1.048758e+10  ...          0.059663
#
#       asset_turnover  inventory_turnover  receivable_turnover  \
# 0           1.231006           -2.743449            43.174808
# 1           1.231006           -2.743449            43.174808
# 2           1.201836           -3.485962            33.806376
# 3           1.223576           -4.055084            24.933942
# 4           1.222587           -2.524234            16.500857
# ...              ...                 ...                  ...
# 3840        0.400845         -107.686291            11.693908
# 3841        0.328422          -81.761252             8.029521
# 3842        0.329579          -56.472028             6.491898
# 3843        0.276943          -88.525491             8.578741
# 3844        0.249675         -110.941730             8.447728
#
#       interest_coverage  retained_to_assets  fx_position_ratio  sales_growth  \
# 0             -4.416966            0.189012          -0.032546           NaN
# 1             -4.416966            0.189012          -0.032546      0.000000
# 2             -9.050283            0.250811          -0.027382      0.173849
# 3            -12.144509            0.294988           0.034318      0.268765
# 4             -8.900462            0.341168           0.020738      0.222102
# ...                 ...                 ...                ...           ...
# 3840          -0.456485           -0.045316          -0.391919      0.045698
# 3841          -0.267753           -0.028656          -0.427720      0.356178
# 3842          -1.162218            0.124824          -0.248413      2.335345
# 3843          -0.181168            0.251601          -0.207227      0.015029
# 3844          -0.082522            0.439776          -0.235390     -0.247065
#
#       asset_growth  net_income_growth
# 0              NaN                NaN
# 1         0.000000           0.000000
# 2         0.202340           0.210271
# 3         0.246222           0.309325
# 4         0.223090           0.194568
# ...            ...                ...
# 3840      0.145326          -1.622454
# 3841      0.655241          -2.170560
# 3842      2.323636        -110.818675
# 3843      0.207947           0.660938
# 3844     -0.164836          -1.149913
#
# [3845 rows x 104 columns]

# %%
print(df_with_ratios.isnull().sum().to_string())
# Out:
# companycode                                                                                                                        0
# ano                                                                                                                                0
# investimentos_em_capital_fixo                                                                                                   1724
# subtotal                                                                                                                           2
# ajustes                                                                                                                         1724
# amortization                                                                                                                    1724
# ativo_fiscal_diferido                                                                                                              2
# ativos_circulantes                                                                                                                 2
# ativos_imobilizados                                                                                                                2
# ativos_intangíveis                                                                                                                 2
# ativos_não_circulantes                                                                                                             2
# aumento_diminuição_líquido_de_caixa_e_equivalentes_de_caixa_antes_do_efeito_das_diferenças_de_conversão_de_moeda_estrangeira    1724
# caixa_gerado_por_atividades_principais                                                                                          1724
# caixa_e_equivalentes_de_caixa                                                                                                      2
# caixa_no_final_do_período                                                                                                       1724
# capital_social_integralizado                                                                                                       2
# contas_a_pagar                                                                                                                     2
# contas_a_receber                                                                                                                   2
# cogs                                                                                                                               2
# despesas_financeiras                                                                                                               2
# despesas_financeiras_não_operacionais                                                                                              2
# despesas_gerais_e_administrativas                                                                                                  2
# despesas_de_amortização                                                                                                            2
# despesas_de_atividades_de_investimento                                                                                          1724
# despesas_de_marketing_vendas_e_distribuição                                                                                        2
# dívidas_financeiras                                                                                                                2
# efeito_das_diferenças_de_conversão_de_moeda_estrangeira_sobre_o_caixa_e_equivalentes_de_caixa                                   1724
# estoques                                                                                                                           2
# fluxo_de_caixa_livre                                                                                                            1724
# fluxo_de_caixa_líquido_das_atividades_operacionais                                                                              1724
# fluxo_de_caixa_das_atividades_de_financiamento                                                                                  1724
# fluxo_de_caixa_das_atividades_de_investimento                                                                                   1724
# fluxo_de_caixa_de_outras_atividades_operacionais                                                                                1724
# fluxo_de_caixa_de_outras_atividades_de_financiamento                                                                            1724
# fluxo_de_caixa_de_outras_atividades_de_investimento                                                                             1724
# indenização_por_antiguidade                                                                                                        2
# investimentos_financeiros                                                                                                          2
# lucro__do_período                                                                                                                  2
# lucro_bruto                                                                                                                        2
# ebit                                                                                                                               2
# lucro_prejuízo_líquido_do_período_das_operações_continuadas                                                                        2
# lucro_antes_dos_ajustes                                                                                                         1724
# lucro_bruto_prejuízo_de_atividades_comerciais                                                                                      2
# ebitda                                                                                                                          1724
# lucro_prejuízo_líquido_do_período                                                                                                  2
# lucro_prejuízo_operacional_líquido                                                                                                 2
# lucros_prejuízos_acumulados                                                                                                        2
# mudança_nas_provisões                                                                                                           1724
# mudanças_no_capital_de_giro                                                                                                     1724
# outras_despesas_operacionais                                                                                                       2
# outras_dívidas                                                                                                                     2
# outras_receitas_operacionais                                                                                                       2
# outras_receitas_e_despesas_antes_do_imposto                                                                                        2
# outras_receitas_despesas                                                                                                        1724
# outros_ativos_circulantes                                                                                                          2
# outros_ativos_não_circulantes                                                                                                      2
# outros_itens_do_patrimônio_líquido                                                                                                 2
# outros_passivos_circulantes                                                                                                        2
# outros_recebíveis                                                                                                                  2
# pagamento_de_dividendos                                                                                                         1724
# participações_da_controladora                                                                                                      2
# passivo_fiscal_diferido                                                                                                            2
# passivos_circulantes                                                                                                               2
# passivos_não_circulantes                                                                                                           2
# patrimônio_líquido                                                                                                                 2
# patrimônio_líquido_atribuível_aos_acionistas_da_controladora                                                                       2
# posição_cambial_líquida                                                                                                            2
# posição_cambial_líquida_incluindo_hedge                                                                                         1123
# posição_líquida_ativo_passivo_monetária_em_moeda_estrangeira                                                                    1123
# provisões_de_longo_prazo                                                                                                           2
# provisões_para_dívidas                                                                                                             2
# receita_despesa_de_imposto_diferido                                                                                                2
# receita_despesa_de_imposto_das_operações_continuadas                                                                               2
# receita_despesa_de_imposto_do_período                                                                                              2
# receita_de_vendas                                                                                                                  2
# receitas_financeiras_não_operacionais                                                                                              2
# receitas_de_atividades_de_investimento                                                                                          1724
# reservas_restritas_separadas_do_lucro                                                                                              2
# total_de_ativos                                                                                                                    2
# total_do_passivo_e_patrimônico_líquido                                                                                             2
# valores_de_caixa_no_início_do_período                                                                                           1724
# variação_nas_dívidas_financeiras                                                                                                1724
# variação_no_caixa_e_equivalentes                                                                                                1724
# vendas_domésticas                                                                                                                  2
# vendas_internacionais                                                                                                              2
# ebitda_final                                                                                                                       2
# ebitda_source                                                                                                                      0
# current_ratio                                                                                                                      2
# quick_ratio                                                                                                                        2
# debt_to_equity                                                                                                                     2
# debt_to_assets                                                                                                                     2
# roe                                                                                                                                2
# roa                                                                                                                                2
# net_margin                                                                                                                       100
# operating_margin                                                                                                                 100
# asset_turnover                                                                                                                     2
# inventory_turnover                                                                                                               564
# receivable_turnover                                                                                                              166
# interest_coverage                                                                                                                222
# retained_to_assets                                                                                                                 2
# fx_position_ratio                                                                                                                  2
# sales_growth                                                                                                                     320
# asset_growth                                                                                                                     227
# net_income_growth                                                                                                                242

# %%
df_with_ratios.columns
# Out:
# Index(['companycode', 'ano', 'investimentos_em_capital_fixo', 'subtotal',
#        'ajustes', 'amortization', 'ativo_fiscal_diferido',
#        'ativos_circulantes', 'ativos_imobilizados', 'ativos_intangíveis',
#        ...
#        'operating_margin', 'asset_turnover', 'inventory_turnover',
#        'receivable_turnover', 'interest_coverage', 'retained_to_assets',
#        'fx_position_ratio', 'sales_growth', 'asset_growth',
#        'net_income_growth'],
#       dtype='object', length=104)

# %% [markdown]
# ## Thresholds para avaliar cada sessão de indicadores.

# %% [markdown]
# -----

# %%
from score import score_financial_ratios
df_scored = score_financial_ratios(df_with_ratios)

# %%
pd.set_option('display.max_columns', None)
df_scored.head()
# Out:
#   companycode   ano  investimentos_em_capital_fixo    subtotal  ajustes  \
# 0        ADEL  2008                            NaN  27018810.5      NaN
# 1        ADEL  2009                            NaN  27018810.5      NaN
# 2        ADEL  2010                            NaN  33872750.5      NaN
# 3        ADEL  2011                            NaN  43914250.0      NaN
# 4        ADEL  2012                            NaN  54610053.0      NaN
#
#    amortization  ativo_fiscal_diferido  ativos_circulantes  \
# 0           NaN                    0.0          45582654.0
# 1           NaN                    0.0          45582654.0
# 2           NaN                    0.0          58621451.0
# 3           NaN               113998.0          75550839.0
# 4           NaN               346418.0          93484162.0
#
#    ativos_imobilizados  ativos_intangíveis  ativos_não_circulantes  \
# 0           14716940.0             59884.0              15170747.0
# 1           14716940.0             59884.0              15170747.0
# 2           13861696.0            125804.0              14424814.0
# 3           14762743.0            145293.0              15481001.0
# 4           16136254.0            175550.0              17855965.0
#
#    aumento_diminuição_líquido_de_caixa_e_equivalentes_de_caixa_antes_do_efeito_das_diferenças_de_conversão_de_moeda_estrangeira  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    caixa_gerado_por_atividades_principais  caixa_e_equivalentes_de_caixa  \
# 0                                     NaN                     12278966.0
# 1                                     NaN                     12278966.0
# 2                                     NaN                     23356948.0
# 3                                     NaN                     32365348.0
# 4                                     NaN                      9840553.0
#
#    caixa_no_final_do_período  capital_social_integralizado  contas_a_pagar  \
# 0                        NaN                     7875000.0        658880.0
# 1                        NaN                     7875000.0        658880.0
# 2                        NaN                     7875000.0        738391.0
# 3                        NaN                     7875000.0       1148007.5
# 4                        NaN                     7875000.0       1307174.5
#
#    contas_a_receber        cogs  despesas_financeiras  \
# 0         1732209.5 -36969117.0            -4467984.0
# 1         1732209.5 -36969117.0            -4467984.0
# 2         2596836.0 -45050840.0            -2562968.0
# 3         4467178.5 -56331016.0            -2482437.0
# 4         8249453.0 -68996586.0            -4188750.0
#
#    despesas_financeiras_não_operacionais  despesas_gerais_e_administrativas  \
# 0                             -4467984.0                         -9045449.0
# 1                             -4467984.0                         -9045449.0
# 2                             -2562968.0                         -7589462.0
# 3                             -2482437.0                         -9018396.0
# 4                             -4188750.0                        -10401230.0
#
#    despesas_de_amortização  despesas_de_atividades_de_investimento  \
# 0                1438882.0                                     NaN
# 1                1438882.0                                     NaN
# 2                1403045.0                                     NaN
# 3                1475577.0                                     NaN
# 4                1708557.0                                     NaN
#
#    despesas_de_marketing_vendas_e_distribuição  dívidas_financeiras  \
# 0                                   -9038311.0            1732469.5
# 1                                   -9038311.0            1732469.5
# 2                                  -11953725.0            1451071.5
# 3                                  -15879110.0            1881790.0
# 4                                  -19440111.0            2152682.5
#
#    efeito_das_diferenças_de_conversão_de_moeda_estrangeira_sobre_o_caixa_e_equivalentes_de_caixa  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#      estoques  fluxo_de_caixa_livre  \
# 0  13475416.0                   NaN
# 1  13475416.0                   NaN
# 2  12923503.0                   NaN
# 3  13891455.5                   NaN
# 4  27333673.5                   NaN
#
#    fluxo_de_caixa_líquido_das_atividades_operacionais  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    fluxo_de_caixa_das_atividades_de_financiamento  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    fluxo_de_caixa_das_atividades_de_investimento  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    fluxo_de_caixa_de_outras_atividades_operacionais  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    fluxo_de_caixa_de_outras_atividades_de_financiamento  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    fluxo_de_caixa_de_outras_atividades_de_investimento  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    indenização_por_antiguidade  investimentos_financeiros  lucro__do_período  \
# 0                      23657.0                   137640.0         13716498.0
# 1                      23657.0                   137640.0         13716498.0
# 2                     480984.0                   116992.5         16600678.0
# 3                     824494.0                   116992.5         21735688.0
# 4                     790181.0                   116992.5         25964758.0
#
#    lucro_bruto        ebit  \
# 0   37818695.0  20780514.0
# 1   37818695.0  20780514.0
# 2   42738773.0  22939135.0
# 3   55053355.0  28733473.0
# 4   67126458.0  35366213.0
#
#    lucro_prejuízo_líquido_do_período_das_operações_continuadas  \
# 0                                         13716498.0
# 1                                         13716498.0
# 2                                         16600678.0
# 3                                         21735688.0
# 4                                         25964758.0
#
#    lucro_antes_dos_ajustes  lucro_bruto_prejuízo_de_atividades_comerciais  \
# 0                      NaN                                     37818695.0
# 1                      NaN                                     37818695.0
# 2                      NaN                                     42738773.0
# 3                      NaN                                     55053355.0
# 4                      NaN                                     67126458.0
#
#    ebitda  lucro_prejuízo_líquido_do_período  \
# 0     NaN                         13716499.0
# 1     NaN                         13716499.0
# 2     NaN                         16600678.0
# 3     NaN                         21735688.0
# 4     NaN                         25964758.0
#
#    lucro_prejuízo_operacional_líquido  lucros_prejuízos_acumulados  \
# 0                          19734935.0                   11483129.0
# 1                          19734935.0                   11483129.0
# 2                          23195586.0                   18320837.0
# 3                          30147979.0                   26853310.0
# 4                          37281811.0                   37985711.0
#
#    mudança_nas_provisões  mudanças_no_capital_de_giro  \
# 0                    NaN                          NaN
# 1                    NaN                          NaN
# 2                    NaN                          NaN
# 3                    NaN                          NaN
# 4                    NaN                          NaN
#
#    outras_despesas_operacionais  outras_dívidas  outras_receitas_operacionais  \
# 0                    -1030166.0        597917.5                     2075745.0
# 1                    -1030166.0        597917.5                     2075745.0
# 2                    -1076721.0        545239.0                      820270.0
# 3                    -1717388.0        615901.0                      302882.0
# 4                    -2016454.0       1263056.0                      100856.0
#
#    outras_receitas_e_despesas_antes_do_imposto  outras_receitas_despesas  \
# 0                                          0.0                       NaN
# 1                                          0.0                       NaN
# 2                                          0.0                       NaN
# 3                                          0.0                       NaN
# 4                                          0.0                       NaN
#
#    outros_ativos_circulantes  outros_ativos_não_circulantes  \
# 0                  2870280.0                        60072.0
# 1                  2870280.0                        60072.0
# 2                  4188201.0                        48000.0
# 3                  6437733.0                        36000.0
# 4                 11848639.0                       109272.0
#
#    outros_itens_do_patrimônio_líquido  outros_passivos_circulantes  \
# 0                          13374985.0                    2404738.0
# 1                          13374985.0                    2404738.0
# 2                          13374985.0                    3582952.0
# 3                          13374985.0                    4914569.0
# 4                          13374985.0                    6218423.0
#
#    outros_recebíveis  pagamento_de_dividendos  participações_da_controladora  \
# 0            38364.0                      NaN                     13716498.0
# 1            38364.0                      NaN                     13716498.0
# 2            95476.5                      NaN                     16600678.0
# 3           109736.0                      NaN                     21735688.0
# 4           314358.5                      NaN                     25964758.0
#
#    passivo_fiscal_diferido  passivos_circulantes  passivos_não_circulantes  \
# 0                 240032.0             8454967.0                 2891157.0
# 1                 240032.0             8454967.0                 2891157.0
# 2                      0.0             9124050.0                 3021037.0
# 3                      0.0            12277661.0                 3465092.0
# 4                      0.0            15735944.0                 4088511.0
#
#    patrimônio_líquido  \
# 0          49407277.0
# 1          49407277.0
# 2          60901178.0
# 3          75289087.0
# 4          91515672.0
#
#    patrimônio_líquido_atribuível_aos_acionistas_da_controladora  \
# 0                                         49407277.0
# 1                                         49407277.0
# 2                                         60901178.0
# 3                                         75289087.0
# 4                                         91515672.0
#
#    posição_cambial_líquida  posição_cambial_líquida_incluindo_hedge  \
# 0               -1977267.0                                      NaN
# 1               -1977267.0                                      NaN
# 2               -2000179.0                                      NaN
# 3                3124046.0                                      NaN
# 4                2308966.0                                      NaN
#
#    posição_líquida_ativo_passivo_monetária_em_moeda_estrangeira  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    provisões_de_longo_prazo  provisões_para_dívidas  \
# 0                       0.0                 71695.0
# 1                       0.0                 71695.0
# 2                       0.0                 71695.0
# 3                       0.0                 71695.0
# 4                       0.0                 71695.0
#
#    receita_despesa_de_imposto_diferido  \
# 0                             165930.0
# 1                             165930.0
# 2                             149227.0
# 3                             204803.0
# 4                             232420.0
#
#    receita_despesa_de_imposto_das_operações_continuadas  \
# 0                                         -3107222.0
# 1                                         -3107222.0
# 2                                         -4197093.0
# 3                                         -5483481.0
# 4                                         -6586621.0
#
#    receita_despesa_de_imposto_do_período  receita_de_vendas  \
# 0                             -3273152.0         74787812.0
# 1                             -3273152.0         74787812.0
# 2                             -4346320.0         87789613.0
# 3                             -5688284.0        111384371.0
# 4                             -6819041.0        136123044.0
#
#    receitas_financeiras_não_operacionais  \
# 0                               511190.0
# 1                               511190.0
# 2                               421604.0
# 3                               968133.0
# 4                              1373916.0
#
#    receitas_de_atividades_de_investimento  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    reservas_restritas_separadas_do_lucro  total_de_ativos  \
# 0                              2957664.0       60753401.0
# 1                              2957664.0       60753401.0
# 2                              4729678.0       73046265.0
# 3                              5450104.0       91031840.0
# 4                              6378203.0      111340127.0
#
#    total_do_passivo_e_patrimônico_líquido  \
# 0                              60753401.0
# 1                              60753401.0
# 2                              73046265.0
# 3                              91031840.0
# 4                             111340127.0
#
#    valores_de_caixa_no_início_do_período  variação_nas_dívidas_financeiras  \
# 0                                    NaN                               NaN
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
#
#    variação_no_caixa_e_equivalentes  vendas_domésticas  vendas_internacionais  \
# 0                               NaN         87260709.0              4865016.0
# 1                               NaN         87260709.0              4865016.0
# 2                               NaN        104427004.0              5399918.0
# 3                               NaN        132355741.0              6157158.0
# 4                               NaN        162911678.0              7611179.0
#
#    ebitda_final ebitda_source  current_ratio  quick_ratio  debt_to_equity  \
# 0   23818184.05     Estimated       5.391228     1.996632        0.035065
# 1   23818184.05     Estimated       5.391228     1.996632        0.035065
# 2   26591448.25     Estimated       6.424938     3.303575        0.023827
# 3   33285065.00     Estimated       6.153521     3.524308        0.024994
# 4   40933219.35     Estimated       5.940804     1.902564        0.023523
#
#    debt_to_assets       roe       roa  net_margin  operating_margin  \
# 0        0.028516  0.277621  0.225773    0.183406          0.263879
# 1        0.028516  0.277621  0.225773    0.183406          0.263879
# 2        0.019865  0.272584  0.227263    0.189096          0.264218
# 3        0.020672  0.288696  0.238770    0.195141          0.270666
# 4        0.019334  0.283719  0.233202    0.190745          0.273883
#
#    asset_turnover  inventory_turnover  receivable_turnover  interest_coverage  \
# 0        1.231006           -2.743449            43.174808          -4.416966
# 1        1.231006           -2.743449            43.174808          -4.416966
# 2        1.201836           -3.485962            33.806376          -9.050283
# 3        1.223576           -4.055084            24.933942         -12.144509
# 4        1.222587           -2.524234            16.500857          -8.900462
#
#    retained_to_assets  fx_position_ratio  sales_growth  asset_growth  \
# 0            0.189012          -0.032546      0.000000      0.000000
# 1            0.189012          -0.032546      0.000000      0.000000
# 2            0.250811          -0.027382      0.173849      0.202340
# 3            0.294988           0.034318      0.268765      0.246222
# 4            0.341168           0.020738      0.222102      0.223090
#
#    net_income_growth  ebitda_margin  ebitda_to_interest  ebitda_to_debt  \
# 0           0.000000       0.318477           -5.330857       13.748112
# 1           0.000000       0.318477           -5.330857       13.748112
# 2           0.210271       0.302900          -10.375256       18.325388
# 3           0.309325       0.298831          -13.408221       17.687981
# 4           0.194568       0.300707           -9.772180       19.014982
#
#    score_ebitda_margin  score_ebitda_to_interest  score_ebitda_to_debt  \
# 0                   10                         0                    10
# 1                   10                         0                    10
# 2                   10                         0                    10
# 3                   10                         0                    10
# 4                   10                         0                    10
#
#    score_roe  score_roa  score_net_margin  score_operating_margin  \
# 0         10         10                10                      10
# 1         10         10                10                      10
# 2         10         10                10                      10
# 3         10         10                10                      10
# 4         10         10                10                      10
#
#    score_current_ratio  score_quick_ratio  score_debt_to_equity  \
# 0                   10                 10                    10
# 1                   10                 10                    10
# 2                   10                 10                    10
# 3                   10                 10                    10
# 4                   10                 10                    10
#
#    score_debt_to_assets  score_interest_coverage  score_retained_to_assets  \
# 0                    10                        0                         8
# 1                    10                        0                         8
# 2                    10                        0                         8
# 3                    10                        0                         8
# 4                    10                        0                        10
#
#    score_asset_turnover  score_inventory_turnover  score_receivable_turnover  \
# 0                    10                         0                         10
# 1                    10                         0                         10
# 2                    10                         0                         10
# 3                    10                         0                         10
# 4                    10                         0                         10
#
#    score_sales_growth  score_asset_growth  score_net_income_growth  \
# 0                   4                   4                        4
# 1                   4                   4                        4
# 2                  10                  10                       10
# 3                  10                  10                       10
# 4                  10                  10                        8
#
#    score_fx_position_ratio  total_score
# 0                        5         7.25
# 1                        5         7.25
# 2                        5         8.15
# 3                        8         8.30
# 4                        8         8.30

# %%
df_scored['total_score'].mean()
# Out:
# np.float64(5.20888166449935)

# %%
df_scored['total_score'].max()
# Out:
# np.float64(8.6)

# %%
df_scored['total_score'].min()
# Out:
# np.float64(1.3)

# %%
df_scored['total_score'].unique()
# Out:
# array([7.25, 8.15, 8.3 , 7.75, 6.25, 7.15, 4.4 , 5.4 , 4.85, 4.65, 6.75,
#        5.5 , 6.2 , 6.65, 6.55, 6.15, 6.95, 6.05, 5.1 , 5.75, 7.5 , 7.7 ,
#        4.55, 5.7 , 5.8 , 6.9 , 3.85, 2.25, 5.05, 7.  , 7.55, 5.3 , 5.65,
#        6.8 , 6.4 , 4.25, 4.95, 4.45, 5.55, 5.45, 7.05, 5.2 , 6.5 , 4.8 ,
#        4.9 , 5.  , 5.9 , 5.6 , 5.95, 6.3 , 6.35, 5.35, 7.2 , 6.85, 6.45,
#        3.2 , 4.3 , 3.9 , 3.4 , 2.65, 4.2 , 6.6 , 3.15, 7.4 , 6.1 , 5.85,
#        2.95, 3.5 , 2.7 , 4.05, 3.65, 6.7 , 4.75, 5.25, 4.35, 4.6 , 7.1 ,
#        7.85, 7.3 , 6.  , 7.65, 7.8 , 8.05, 8.1 , 8.5 , 3.55, 2.4 , 2.15,
#        4.5 , 4.1 , 4.7 , 7.6 , 3.6 , 3.75, 3.25, 4.  , 3.45, 2.5 , 4.15,
#        3.8 , 3.3 , 2.55, 7.95, 2.9 , 3.1 , 3.95, 3.7 , 3.35, 7.35, 2.6 ,
#        2.75, 7.45, 3.  , 3.05, 5.15, 2.3 , 1.5 , 1.75, 2.  , 2.85, 2.8 ,
#        8.25, 7.9 , 8.  , 2.1 , 2.45, 8.4 , 8.6 , 1.3 , 1.9 , 2.2 , 1.55,
#        2.35, 8.2 , 1.45, 1.95, 1.7 , 1.65, 2.05, 8.45, 8.35])

# %%
df_scored['total_score'].nunique()
# Out:
# 141

# %%
df_scored.columns.tolist()
# Out:
# ['companycode',
#  'ano',
#  'investimentos_em_capital_fixo',
#  'subtotal',
#  'ajustes',
#  'amortization',
#  'ativo_fiscal_diferido',
#  'ativos_circulantes',
#  'ativos_imobilizados',
#  'ativos_intangíveis',
#  'ativos_não_circulantes',
#  'aumento_diminuição_líquido_de_caixa_e_equivalentes_de_caixa_antes_do_efeito_das_diferenças_de_conversão_de_moeda_estrangeira',
#  'caixa_gerado_por_atividades_principais',
#  'caixa_e_equivalentes_de_caixa',
#  'caixa_no_final_do_período',
#  'capital_social_integralizado',
#  'contas_a_pagar',
#  'contas_a_receber',
#  'cogs',
#  'despesas_financeiras',
#  'despesas_financeiras_não_operacionais',
#  'despesas_gerais_e_administrativas',
#  'despesas_de_amortização',
#  'despesas_de_atividades_de_investimento',
#  'despesas_de_marketing_vendas_e_distribuição',
#  'dívidas_financeiras',
#  'efeito_das_diferenças_de_conversão_de_moeda_estrangeira_sobre_o_caixa_e_equivalentes_de_caixa',
#  'estoques',
#  'fluxo_de_caixa_livre',
#  'fluxo_de_caixa_líquido_das_atividades_operacionais',
#  'fluxo_de_caixa_das_atividades_de_financiamento',
#  'fluxo_de_caixa_das_atividades_de_investimento',
#  'fluxo_de_caixa_de_outras_atividades_operacionais',
#  'fluxo_de_caixa_de_outras_atividades_de_financiamento',
#  'fluxo_de_caixa_de_outras_atividades_de_investimento',
#  'indenização_por_antiguidade',
#  'investimentos_financeiros',
#  'lucro__do_período',
#  'lucro_bruto',
#  'ebit',
#  'lucro_prejuízo_líquido_do_período_das_operações_continuadas',
#  'lucro_antes_dos_ajustes',
#  'lucro_bruto_prejuízo_de_atividades_comerciais',
#  'ebitda',
#  'lucro_prejuízo_líquido_do_período',
#  'lucro_prejuízo_operacional_líquido',
#  'lucros_prejuízos_acumulados',
#  'mudança_nas_provisões',
#  'mudanças_no_capital_de_giro',
#  'outras_despesas_operacionais',
#  'outras_dívidas',
#  'outras_receitas_operacionais',
#  'outras_receitas_e_despesas_antes_do_imposto',
#  'outras_receitas_despesas',
#  'outros_ativos_circulantes',
#  'outros_ativos_não_circulantes',
#  'outros_itens_do_patrimônio_líquido',
#  'outros_passivos_circulantes',
#  'outros_recebíveis',
#  'pagamento_de_dividendos',
#  'participações_da_controladora',
#  'passivo_fiscal_diferido',
#  'passivos_circulantes',
#  'passivos_não_circulantes',
#  'patrimônio_líquido',
#  'patrimônio_líquido_atribuível_aos_acionistas_da_controladora',
#  'posição_cambial_líquida',
#  'posição_cambial_líquida_incluindo_hedge',
#  'posição_líquida_ativo_passivo_monetária_em_moeda_estrangeira',
#  'provisões_de_longo_prazo',
#  'provisões_para_dívidas',
#  'receita_despesa_de_imposto_diferido',
#  'receita_despesa_de_imposto_das_operações_continuadas',
#  'receita_despesa_de_imposto_do_período',
#  'receita_de_vendas',
#  'receitas_financeiras_não_operacionais',
#  'receitas_de_atividades_de_investimento',
#  'reservas_restritas_separadas_do_lucro',
#  'total_de_ativos',
#  'total_do_passivo_e_patrimônico_líquido',
#  'valores_de_caixa_no_início_do_período',
#  'variação_nas_dívidas_financeiras',
#  'variação_no_caixa_e_equivalentes',
#  'vendas_domésticas',
#  'vendas_internacionais',
#  'ebitda_final',
#  'ebitda_source',
#  'current_ratio',
#  'quick_ratio',
#  'debt_to_equity',
#  'debt_to_assets',
#  'roe',
#  'roa',
#  'net_margin',
#  'operating_margin',
#  'asset_turnover',
#  'inventory_turnover',
#  'receivable_turnover',
#  'interest_coverage',
#  'retained_to_assets',
#  'fx_position_ratio',
#  'sales_growth',
#  'asset_growth',
#  'net_income_growth',
#  'ebitda_margin',
#  'ebitda_to_interest',
#  'ebitda_to_debt',
#  'score_ebitda_margin',
#  'score_ebitda_to_interest',
#  'score_ebitda_to_debt',
#  'score_roe',
#  'score_roa',
#  'score_net_margin',
#  'score_operating_margin',
#  'score_current_ratio',
#  'score_quick_ratio',
#  'score_debt_to_equity',
#  'score_debt_to_assets',
#  'score_interest_coverage',
#  'score_retained_to_assets',
#  'score_asset_turnover',
#  'score_inventory_turnover',
#  'score_receivable_turnover',
#  'score_sales_growth',
#  'score_asset_growth',
#  'score_net_income_growth',
#  'score_fx_position_ratio',
#  'total_score']

# %% [markdown]
# ##

# %%
# 1. Defina a lista de colunas a serem removidas não utilizadas
colunas_para_remover = [
    'investimentos_em_capital_fixo', 'subtotal', 'ajustes', 'ativos_imobilizados',
    'ativos_intangíveis', 'ativos_não_circulantes', 'caixa_no_final_do_período',
    'capital_social_integralizado', 'contas_a_pagar', 'despesas_financeiras_não_operacionais',
    'despesas_gerais_e_administrativas', 'despesas_de_amortização',
    'despesas_de_atividades_de_investimento', 'despesas_de_marketing_vendas_e_distribuição',
    'fluxo_de_caixa_livre', 'investimentos_financeiros', 'lucro__do_período',
    'lucro_bruto', 'lucro_prejuízo_líquido_do_período_das_operações_continuadas',
    'lucro_bruto_prejuízo_de_atividades_comerciais', 'outras_despesas_operacionais',
    'outras_dívidas', 'outras_receitas_operacionais',
    'outras_receitas_e_despesas_antes_do_imposto', 'outros_ativos_não_circulantes',
    'outros_itens_do_patrimônio_líquido', 'outros_passivos_circulantes',
    'outros_recebíveis', 'participações_da_controladora', 'passivo_fiscal_diferido',
    'passivos_não_circulantes', 'patrimônio_líquido_atribuível_aos_acionistas_da_controladora',
    'provisões_de_longo_prazo', 'provisões_para_dívidas',
    'receita_despesa_de_imposto_diferido',
    'receita_despesa_de_imposto_das_operações_continuadas',
    'receita_despesa_de_imposto_do_período', 'receitas_financeiras_não_operacionais',
    'reservas_restritas_separadas_do_lucro', 'total_do_passivo_e_patrimônico_líquido',
    'vendas_domésticas', 'vendas_internacionais',
]

df_model = df_scored.drop(columns=colunas_para_remover, errors='ignore')

# 3. Verifique o resultado
print(f"Colunas antes do drop: {df_scored.shape[1]}")
print(f"Colunas após o drop: {df_model.shape[1]}")
print("\nColunas restantes para o modelo:")
print(df_model.columns.to_list())
# Out:
# Colunas antes do drop: 128
# Colunas após o drop: 86
#
# Colunas restantes para o modelo:
# ['companycode', 'ano', 'amortization', 'ativo_fiscal_diferido', 'ativos_circulantes', 'aumento_diminuição_líquido_de_caixa_e_equivalentes_de_caixa_antes_do_efeito_das_diferenças_de_conversão_de_moeda_estrangeira', 'caixa_gerado_por_atividades_principais', 'caixa_e_equivalentes_de_caixa', 'contas_a_receber', 'cogs', 'despesas_financeiras', 'dívidas_financeiras', 'efeito_das_diferenças_de_conversão_de_moeda_estrangeira_sobre_o_caixa_e_equivalentes_de_caixa', 'estoques', 'fluxo_de_caixa_líquido_das_atividades_operacionais', 'fluxo_de_caixa_das_atividades_de_financiamento', 'fluxo_de_caixa_das_atividades_de_investimento', 'fluxo_de_caixa_de_outras_atividades_operacionais', 'fluxo_de_caixa_de_outras_atividades_de_financiamento', 'fluxo_de_caixa_de_outras_atividades_de_investimento', 'indenização_por_antiguidade', 'ebit', 'lucro_antes_dos_ajustes', 'ebitda', 'lucro_prejuízo_líquido_do_período', 'lucro_prejuízo_operacional_líquido', 'lucros_prejuízos_acumulados', 'mudança_nas_provisões', 'mudanças_no_capital_de_giro', 'outras_receitas_despesas', 'outros_ativos_circulantes', 'pagamento_de_dividendos', 'passivos_circulantes', 'patrimônio_líquido', 'posição_cambial_líquida', 'posição_cambial_líquida_incluindo_hedge', 'posição_líquida_ativo_passivo_monetária_em_moeda_estrangeira', 'receita_de_vendas', 'receitas_de_atividades_de_investimento', 'total_de_ativos', 'valores_de_caixa_no_início_do_período', 'variação_nas_dívidas_financeiras', 'variação_no_caixa_e_equivalentes', 'ebitda_final', 'ebitda_source', 'current_ratio', 'quick_ratio', 'debt_to_equity', 'debt_to_assets', 'roe', 'roa', 'net_margin', 'operating_margin', 'asset_turnover', 'inventory_turnover', 'receivable_turnover', 'interest_coverage', 'retained_to_assets', 'fx_position_ratio', 'sales_growth', 'asset_growth', 'net_income_growth', 'ebitda_margin', 'ebitda_to_interest', 'ebitda_to_debt', 'score_ebitda_margin', 'score_ebitda_to_interest', 'score_ebitda_to_debt', 'score_roe', 'score_roa', 'score_net_margin', 'score_operating_margin', 'score_current_ratio', 'score_quick_ratio', 'score_debt_to_equity', 'score_debt_to_assets', 'score_interest_coverage', 'score_retained_to_assets', 'score_asset_turnover', 'score_inventory_turnover', 'score_receivable_turnover', 'score_sales_growth', 'score_asset_growth', 'score_net_income_growth', 'score_fx_position_ratio', 'total_score']

# %%
df_model = df_scored.copy()

# %%
dicionario_colunas = {
    # Ratios Originais
    'current_ratio': 'liquidez_corrente',
    'quick_ratio': 'liquidez_seca',
    'debt_to_equity': 'divida_sobre_pl',
    'debt_to_assets': 'divida_sobre_ativos',
    'net_margin': 'margem_liquida',
    'operating_margin': 'margem_operacional',
    'asset_turnover': 'giro_do_ativo',
    'inventory_turnover': 'giro_de_estoque',
    'receivable_turnover': 'giro_de_recebiveis',
    'interest_coverage': 'cobertura_de_juros',
    'retained_to_assets': 'lucros_retidos_sobre_ativos',
    'fx_position_ratio': 'razao_posicao_cambial',
    'sales_growth': 'crescimento_vendas',
    'asset_growth': 'crescimento_ativos',
    'net_income_growth': 'crescimento_lucro_liquido',
    'ebitda_margin': 'margem_ebitda',
    'ebitda_to_interest': 'ebitda_sobre_juros',
    'ebitda_to_debt': 'ebitda_sobre_divida',

    # Colunas de Score
    'score_ebitda_margin': 'pontuacao_margem_ebitda',
    'score_ebitda_to_interest': 'pontuacao_ebitda_sobre_juros',
    'score_ebitda_to_debt': 'pontuacao_ebitda_sobre_divida',
    'score_roe': 'pontuacao_roe',
    'score_roa': 'pontuacao_roa',
    'score_net_margin': 'pontuacao_margem_liquida',
    'score_operating_margin': 'pontuacao_margem_operacional',
    'score_current_ratio': 'pontuacao_liquidez_corrente',
    'score_quick_ratio': 'pontuacao_liquidez_seca',
    'score_debt_to_equity': 'pontuacao_divida_sobre_pl',
    'score_debt_to_assets': 'pontuacao_divida_sobre_ativos',
    'score_interest_coverage': 'pontuacao_cobertura_de_juros',
    'score_retained_to_assets': 'pontuacao_lucros_retidos_sobre_ativos',
    'score_asset_turnover': 'pontuacao_giro_do_ativo',
    'score_inventory_turnover': 'pontuacao_giro_de_estoque',
    'score_receivable_turnover': 'pontuacao_giro_de_recebiveis',
    'score_sales_growth': 'pontuacao_crescimento_vendas',
    'score_asset_growth': 'pontuacao_crescimento_ativos',
    'score_net_income_growth': 'pontuacao_crescimento_lucro_liquido',
    'score_fx_position_ratio': 'pontuacao_razao_posicao_cambial',
    'ebitda_final': 'ebitda',
}

# --- Como Usar ---
# Assumindo que seu dataframe se chama df_modelo_final

df_model = df_model.rename(columns=dicionario_colunas)

# Verificar o resultado
print("Colunas renomeadas:")
print(df_model.columns.to_list())
# Out:
# Colunas renomeadas:
# ['companycode', 'ano', 'investimentos_em_capital_fixo', 'subtotal', 'ajustes', 'amortization', 'ativo_fiscal_diferido', 'ativos_circulantes', 'ativos_imobilizados', 'ativos_intangíveis', 'ativos_não_circulantes', 'aumento_diminuição_líquido_de_caixa_e_equivalentes_de_caixa_antes_do_efeito_das_diferenças_de_conversão_de_moeda_estrangeira', 'caixa_gerado_por_atividades_principais', 'caixa_e_equivalentes_de_caixa', 'caixa_no_final_do_período', 'capital_social_integralizado', 'contas_a_pagar', 'contas_a_receber', 'cogs', 'despesas_financeiras', 'despesas_financeiras_não_operacionais', 'despesas_gerais_e_administrativas', 'despesas_de_amortização', 'despesas_de_atividades_de_investimento', 'despesas_de_marketing_vendas_e_distribuição', 'dívidas_financeiras', 'efeito_das_diferenças_de_conversão_de_moeda_estrangeira_sobre_o_caixa_e_equivalentes_de_caixa', 'estoques', 'fluxo_de_caixa_livre', 'fluxo_de_caixa_líquido_das_atividades_operacionais', 'fluxo_de_caixa_das_atividades_de_financiamento', 'fluxo_de_caixa_das_atividades_de_investimento', 'fluxo_de_caixa_de_outras_atividades_operacionais', 'fluxo_de_caixa_de_outras_atividades_de_financiamento', 'fluxo_de_caixa_de_outras_atividades_de_investimento', 'indenização_por_antiguidade', 'investimentos_financeiros', 'lucro__do_período', 'lucro_bruto', 'ebit', 'lucro_prejuízo_líquido_do_período_das_operações_continuadas', 'lucro_antes_dos_ajustes', 'lucro_bruto_prejuízo_de_atividades_comerciais', 'ebitda', 'lucro_prejuízo_líquido_do_período', 'lucro_prejuízo_operacional_líquido', 'lucros_prejuízos_acumulados', 'mudança_nas_provisões', 'mudanças_no_capital_de_giro', 'outras_despesas_operacionais', 'outras_dívidas', 'outras_receitas_operacionais', 'outras_receitas_e_despesas_antes_do_imposto', 'outras_receitas_despesas', 'outros_ativos_circulantes', 'outros_ativos_não_circulantes', 'outros_itens_do_patrimônio_líquido', 'outros_passivos_circulantes', 'outros_recebíveis', 'pagamento_de_dividendos', 'participações_da_controladora', 'passivo_fiscal_diferido', 'passivos_circulantes', 'passivos_não_circulantes', 'patrimônio_líquido', 'patrimônio_líquido_atribuível_aos_acionistas_da_controladora', 'posição_cambial_líquida', 'posição_cambial_líquida_incluindo_hedge', 'posição_líquida_ativo_passivo_monetária_em_moeda_estrangeira', 'provisões_de_longo_prazo', 'provisões_para_dívidas', 'receita_despesa_de_imposto_diferido', 'receita_despesa_de_imposto_das_operações_continuadas', 'receita_despesa_de_imposto_do_período', 'receita_de_vendas', 'receitas_financeiras_não_operacionais', 'receitas_de_atividades_de_investimento', 'reservas_restritas_separadas_do_lucro', 'total_de_ativos', 'total_do_passivo_e_patrimônico_líquido', 'valores_de_caixa_no_início_do_período', 'variação_nas_dívidas_financeiras', 'variação_no_caixa_e_equivalentes', 'vendas_domésticas', 'vendas_internacionais', 'ebitda', 'ebitda_source', 'liquidez_corrente', 'liquidez_seca', 'divida_sobre_pl', 'divida_sobre_ativos', 'roe', 'roa', 'margem_liquida', 'margem_operacional', 'giro_do_ativo', 'giro_de_estoque', 'giro_de_recebiveis', 'cobertura_de_juros', 'lucros_retidos_sobre_ativos', 'razao_posicao_cambial', 'crescimento_vendas', 'crescimento_ativos', 'crescimento_lucro_liquido', 'margem_ebitda', 'ebitda_sobre_juros', 'ebitda_sobre_divida', 'pontuacao_margem_ebitda', 'pontuacao_ebitda_sobre_juros', 'pontuacao_ebitda_sobre_divida', 'pontuacao_roe', 'pontuacao_roa', 'pontuacao_margem_liquida', 'pontuacao_margem_operacional', 'pontuacao_liquidez_corrente', 'pontuacao_liquidez_seca', 'pontuacao_divida_sobre_pl', 'pontuacao_divida_sobre_ativos', 'pontuacao_cobertura_de_juros', 'pontuacao_lucros_retidos_sobre_ativos', 'pontuacao_giro_do_ativo', 'pontuacao_giro_de_estoque', 'pontuacao_giro_de_recebiveis', 'pontuacao_crescimento_vendas', 'pontuacao_crescimento_ativos', 'pontuacao_crescimento_lucro_liquido', 'pontuacao_razao_posicao_cambial', 'total_score']

# %%
df_model
# Out:
#      companycode   ano  investimentos_em_capital_fixo      subtotal  \
# 0           ADEL  2008                            NaN  2.701881e+07
# 1           ADEL  2009                            NaN  2.701881e+07
# 2           ADEL  2010                            NaN  3.387275e+07
# 3           ADEL  2011                            NaN  4.391425e+07
# 4           ADEL  2012                            NaN  5.461005e+07
# ...          ...   ...                            ...           ...
# 3840       ZOREN  2020                  -1.881500e+08  6.037722e+09
# 3841       ZOREN  2021                  -3.353620e+08  7.986534e+09
# 3842       ZOREN  2022                  -9.923150e+08  3.006555e+10
# 3843       ZOREN  2023                  -1.219082e+09  2.698698e+10
# 3844       ZOREN  2024                  -1.202219e+09  1.677384e+10
#
#            ajustes  amortization  ativo_fiscal_diferido  ativos_circulantes  \
# 0              NaN           NaN           0.000000e+00        4.558265e+07
# 1              NaN           NaN           0.000000e+00        4.558265e+07
# 2              NaN           NaN           0.000000e+00        5.862145e+07
# 3              NaN           NaN           1.139980e+05        7.555084e+07
# 4              NaN           NaN           3.464180e+05        9.348416e+07
# ...            ...           ...                    ...                 ...
# 3840  1.872685e+09  6.032930e+08           4.888430e+08        4.047594e+09
# 3841  2.968941e+09  6.905980e+08           6.717470e+08        6.471306e+09
# 3842 -7.099029e+09  3.668976e+09           1.700569e+09        2.259070e+10
# 3843 -1.209898e+10  6.194368e+09           6.855687e+09        2.862619e+10
# 3844 -7.936120e+08  4.827761e+09           1.057653e+10        1.341005e+10
#
#       ativos_imobilizados  ativos_intangíveis  ativos_não_circulantes  \
# 0            1.471694e+07        5.988400e+04            1.517075e+07
# 1            1.471694e+07        5.988400e+04            1.517075e+07
# 2            1.386170e+07        1.258040e+05            1.442481e+07
# 3            1.476274e+07        1.452930e+05            1.548100e+07
# 4            1.613625e+07        1.755500e+05            1.785596e+07
# ...                   ...                 ...                     ...
# 3840         1.061079e+10        1.506887e+09            1.735498e+10
# 3841         1.878782e+10        1.501186e+09            2.895511e+10
# 3842         5.698022e+10        8.819497e+09            9.515382e+10
# 3843         5.836801e+10        1.106112e+10            1.136030e+11
# 3844         5.496624e+10        1.048758e+10            1.053747e+11
#
#       aumento_diminuição_líquido_de_caixa_e_equivalentes_de_caixa_antes_do_efeito_das_diferenças_de_conversão_de_moeda_estrangeira  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3840                                         17074000.0
# 3841                                        569065000.0
# 3842                                        659141000.0
# 3843                                       -320833000.0
# 3844                                       -622439000.0
#
#       caixa_gerado_por_atividades_principais  caixa_e_equivalentes_de_caixa  \
# 0                                        NaN                   1.227897e+07
# 1                                        NaN                   1.227897e+07
# 2                                        NaN                   2.335695e+07
# 3                                        NaN                   3.236535e+07
# 4                                        NaN                   9.840553e+06
# ...                                      ...                            ...
# 3840                            2.018797e+09                   7.283140e+08
# 3841                            2.158161e+09                   1.171070e+09
# 3842                            3.523400e+09                   3.798939e+09
# 3843                            1.751314e+10                   2.791942e+09
# 3844                            7.230694e+09                   1.541918e+09
#
#       caixa_no_final_do_período  capital_social_integralizado  contas_a_pagar  \
# 0                           NaN                  7.875000e+06    6.588800e+05
# 1                           NaN                  7.875000e+06    6.588800e+05
# 2                           NaN                  7.875000e+06    7.383910e+05
# 3                           NaN                  7.875000e+06    1.148008e+06
# 4                           NaN                  7.875000e+06    1.307174e+06
# ...                         ...                           ...             ...
# 3840               7.099090e+08                  2.000000e+09    9.072905e+08
# 3841               1.161644e+09                  2.500000e+09    1.094957e+09
# 3842               3.779308e+09                  2.500000e+09    4.744087e+09
# 3843               2.779085e+09                  5.000000e+09    2.801182e+09
# 3844               1.443964e+09                  5.000000e+09    2.538530e+09
#
#       contas_a_receber          cogs  despesas_financeiras  \
# 0         1.732210e+06 -3.696912e+07         -4.467984e+06
# 1         1.732210e+06 -3.696912e+07         -4.467984e+06
# 2         2.596836e+06 -4.505084e+07         -2.562968e+06
# 3         4.467178e+06 -5.633102e+07         -2.482437e+06
# 4         8.249453e+06 -6.899659e+07         -4.188750e+06
# ...                ...           ...                   ...
# 3840      7.336395e+08 -7.062390e+09         -2.658892e+09
# 3841      1.449004e+09 -9.771696e+09         -5.464622e+09
# 3842      5.977620e+09 -3.314787e+10         -3.789102e+09
# 3843      4.591502e+09 -3.395732e+10         -1.743802e+10
# 3844      3.510718e+09 -2.594755e+10         -2.144242e+10
#
#       despesas_financeiras_não_operacionais  \
# 0                             -4.467984e+06
# 1                             -4.467984e+06
# 2                             -2.562968e+06
# 3                             -2.482437e+06
# 4                             -4.188750e+06
# ...                                     ...
# 3840                          -2.658892e+09
# 3841                          -5.464622e+09
# 3842                          -3.789102e+09
# 3843                          -1.743802e+10
# 3844                          -2.144242e+10
#
#       despesas_gerais_e_administrativas  despesas_de_amortização  \
# 0                         -9.045449e+06             1.438882e+06
# 1                         -9.045449e+06             1.438882e+06
# 2                         -7.589462e+06             1.403045e+06
# 3                         -9.018396e+06             1.475577e+06
# 4                         -1.040123e+07             1.708557e+06
# ...                                 ...                      ...
# 3840                      -2.659580e+08             6.032930e+08
# 3841                      -3.652870e+08             6.905980e+08
# 3842                      -1.097809e+09             3.668976e+09
# 3843                      -2.036018e+09             6.194368e+09
# 3844                      -1.703544e+09             4.827761e+09
#
#       despesas_de_atividades_de_investimento  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 3840                                     0.0
# 3841                                     0.0
# 3842                                -25000.0
# 3843                              -4125000.0
# 3844                                     0.0
#
#       despesas_de_marketing_vendas_e_distribuição  dívidas_financeiras  \
# 0                                      -9038311.0         1.732470e+06
# 1                                      -9038311.0         1.732470e+06
# 2                                     -11953725.0         1.451072e+06
# 3                                     -15879110.0         1.881790e+06
# 4                                     -19440111.0         2.152682e+06
# ...                                           ...                  ...
# 3840                                  -37021000.0         7.271592e+09
# 3841                                  -34654000.0         1.188988e+10
# 3842                                 -156663000.0         2.831632e+10
# 3843                                 -236760000.0         3.067640e+10
# 3844                                 -237029000.0         2.286454e+10
#
#       efeito_das_diferenças_de_conversão_de_moeda_estrangeira_sobre_o_caixa_e_equivalentes_de_caixa  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3840                                       -130286000.0
# 3841                                       -117330000.0
# 3842                                        -85055000.0
# 3843                                       -211657000.0
# 3844                                        -83485000.0
#
#          estoques  fluxo_de_caixa_livre  \
# 0      13475416.0                   NaN
# 1      13475416.0                   NaN
# 2      12923503.0                   NaN
# 3      13891455.5                   NaN
# 4      27333673.5                   NaN
# ...           ...                   ...
# 3840   65583000.0          1.886462e+09
# 3841  119515000.0          1.731629e+09
# 3842  586978500.0          2.202334e+09
# 3843  383588000.0          1.687585e+10
# 3844  233884500.0          1.017334e+10
#
#       fluxo_de_caixa_líquido_das_atividades_operacionais  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3840                                       1.933705e+09
# 3841                                       2.001211e+09
# 3842                                       3.194649e+09
# 3843                                       1.699001e+10
# 3844                                       6.550147e+09
#
#       fluxo_de_caixa_das_atividades_de_financiamento  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 3840                                   -1.869388e+09
# 3841                                   -1.162564e+09
# 3842                                   -1.543193e+09
# 3843                                   -1.719668e+10
# 3844                                   -1.079578e+10
#
#       fluxo_de_caixa_das_atividades_de_investimento  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 3840                                  -4.724300e+07
# 3841                                  -2.695820e+08
# 3842                                  -9.923150e+08
# 3843                                  -1.141650e+08
# 3844                                   3.623192e+09
#
#       fluxo_de_caixa_de_outras_atividades_operacionais  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 3840                                       -85092000.0
# 3841                                      -156950000.0
# 3842                                      -328751000.0
# 3843                                      -523132000.0
# 3844                                      -680547000.0
#
#       fluxo_de_caixa_de_outras_atividades_de_financiamento  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3840                                      -1.400127e+09
# 3841                                      -1.904509e+09
# 3842                                      -4.463627e+09
# 3843                                      -8.191512e+09
# 3844                                      -8.600854e+09
#
#       fluxo_de_caixa_de_outras_atividades_de_investimento  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3840                                       1.409070e+08
# 3841                                       6.578000e+07
# 3842                                       0.000000e+00
# 3843                                       1.104917e+09
# 3844                                       4.825411e+09
#
#       indenização_por_antiguidade  investimentos_financeiros  \
# 0                         23657.0                   137640.0
# 1                         23657.0                   137640.0
# 2                        480984.0                   116992.5
# 3                        824494.0                   116992.5
# 4                        790181.0                   116992.5
# ...                           ...                        ...
# 3840                    5702000.0                129412000.0
# 3841                   13138000.0                149611000.0
# 3842                   28521000.0                543361000.0
# 3843                   46915000.0                289496000.0
# 3844                   51210000.0                  1410000.0
#
#       lucro__do_período   lucro_bruto          ebit  \
# 0          1.371650e+07  3.781870e+07  2.078051e+07
# 1          1.371650e+07  3.781870e+07  2.078051e+07
# 2          1.660068e+07  4.273877e+07  2.293914e+07
# 3          2.173569e+07  5.505336e+07  2.873347e+07
# 4          2.596476e+07  6.712646e+07  3.536621e+07
# ...                 ...           ...           ...
# 3840       3.820700e+07  1.516723e+09  1.699294e+09
# 3841      -1.594340e+08  1.863112e+09  2.721263e+09
# 3842       9.508736e+09  5.658234e+09  4.965276e+09
# 3843       1.586144e+10  5.431995e+09  4.726298e+09
# 3844      -2.364560e+09  3.710045e+09  1.934896e+09
#
#       lucro_prejuízo_líquido_do_período_das_operações_continuadas  \
# 0                                          1.371650e+07
# 1                                          1.371650e+07
# 2                                          1.660068e+07
# 3                                          2.173569e+07
# 4                                          2.596476e+07
# ...                                                 ...
# 3840                                       3.820700e+07
# 3841                                      -1.594340e+08
# 3842                                       7.299011e+09
# 3843                                       1.556750e+10
# 3844                                      -4.459183e+09
#
#       lucro_antes_dos_ajustes  lucro_bruto_prejuízo_de_atividades_comerciais  \
# 0                         NaN                                   3.781870e+07
# 1                         NaN                                   3.781870e+07
# 2                         NaN                                   4.273877e+07
# 3                         NaN                                   5.505336e+07
# 4                         NaN                                   6.712646e+07
# ...                       ...                                            ...
# 3840             3.820700e+07                                   1.516723e+09
# 3841            -1.594340e+08                                   1.863112e+09
# 3842             9.508736e+09                                   5.658234e+09
# 3843             1.586144e+10                                   5.431995e+09
# 3844            -2.364560e+09                                   3.710045e+09
#
#             ebitda  lucro_prejuízo_líquido_do_período  \
# 0              NaN                       1.371650e+07
# 1              NaN                       1.371650e+07
# 2              NaN                       1.660068e+07
# 3              NaN                       2.173569e+07
# 4              NaN                       2.596476e+07
# ...            ...                                ...
# 3840  1.910892e+09                       7.385100e+07
# 3841  2.809507e+09                      -8.644700e+07
# 3842  2.409707e+09                       9.493495e+09
# 3843  3.762464e+09                       1.576811e+10
# 3844 -3.158172e+09                      -2.363844e+09
#
#       lucro_prejuízo_operacional_líquido  lucros_prejuízos_acumulados  \
# 0                           1.973494e+07                 1.148313e+07
# 1                           1.973494e+07                 1.148313e+07
# 2                           2.319559e+07                 1.832084e+07
# 3                           3.014798e+07                 2.685331e+07
# 4                           3.728181e+07                 3.798571e+07
# ...                                  ...                          ...
# 3840                        1.213744e+09                -9.698870e+08
# 3841                        1.463171e+09                -1.015196e+09
# 3842                        4.403762e+09                 1.469729e+10
# 3843                        3.159217e+09                 3.578501e+10
# 3844                        1.769472e+09                 5.223864e+10
#
#       mudança_nas_provisões  mudanças_no_capital_de_giro  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
# ...                     ...                          ...
# 3840             12673000.0                 1.079050e+08
# 3841             14861000.0                -6.513460e+08
# 3842             42212000.0                 1.113693e+09
# 3843            120561000.0                 1.375068e+10
# 3844             72620000.0                 1.038887e+10
#
#       outras_despesas_operacionais  outras_dívidas  \
# 0                    -1.030166e+06    5.979175e+05
# 1                    -1.030166e+06    5.979175e+05
# 2                    -1.076721e+06    5.452390e+05
# 3                    -1.717388e+06    6.159010e+05
# 4                    -2.016454e+06    1.263056e+06
# ...                            ...             ...
# 3840                 -3.016620e+08    6.672050e+08
# 3841                 -5.780290e+08    6.210815e+08
# 3842                 -9.617650e+08    2.977585e+09
# 3843                 -2.683707e+09    8.926700e+08
# 3844                 -2.756109e+09    1.137576e+09
#
#       outras_receitas_operacionais  \
# 0                     2.075745e+06
# 1                     2.075745e+06
# 2                     8.202700e+05
# 3                     3.028820e+05
# 4                     1.008560e+05
# ...                            ...
# 3840                  7.872120e+08
# 3841                  1.836121e+09
# 3842                  1.523279e+09
# 3843                  4.250788e+09
# 3844                  2.921533e+09
#
#       outras_receitas_e_despesas_antes_do_imposto  outras_receitas_despesas  \
# 0                                    0.000000e+00                       NaN
# 1                                    0.000000e+00                       NaN
# 2                                    0.000000e+00                       NaN
# 3                                    0.000000e+00                       NaN
# 4                                    0.000000e+00                       NaN
# ...                                           ...                       ...
# 3840                                 7.188400e+07              1.256719e+09
# 3841                                 2.098000e+06              2.263482e+09
# 3842                                 6.226000e+06             -1.081022e+10
# 3843                                 5.989492e+09              7.579058e+09
# 3844                                 4.825556e+09              4.744919e+09
#
#       outros_ativos_circulantes  outros_ativos_não_circulantes  \
# 0                  2.870280e+06                   6.007200e+04
# 1                  2.870280e+06                   6.007200e+04
# 2                  4.188201e+06                   4.800000e+04
# 3                  6.437733e+06                   3.600000e+04
# 4                  1.184864e+07                   1.092720e+05
# ...                         ...                            ...
# 3840               5.224780e+08                   2.547678e+09
# 3841               9.716530e+08                   3.351810e+09
# 3842               2.292994e+09                   1.194632e+10
# 3843               3.887571e+09                   1.118269e+10
# 3844               3.864722e+09                   9.442331e+09
#
#       outros_itens_do_patrimônio_líquido  outros_passivos_circulantes  \
# 0                           1.337498e+07                    2404738.0
# 1                           1.337498e+07                    2404738.0
# 2                           1.337498e+07                    3582952.0
# 3                           1.337498e+07                    4914569.0
# 4                           1.337498e+07                    6218423.0
# ...                                  ...                          ...
# 3840                        7.419690e+08                  226928000.0
# 3841                        3.528593e+09                  304973000.0
# 3842                        5.611977e+09                  437804000.0
# 3843                       -4.082518e+09                  686264000.0
# 3844                        6.447430e+08                  514382000.0
#
#       outros_recebíveis  pagamento_de_dividendos  \
# 0          3.836400e+04                      NaN
# 1          3.836400e+04                      NaN
# 2          9.547650e+04                      NaN
# 3          1.097360e+05                      NaN
# 4          3.143585e+05                      NaN
# ...                 ...                      ...
# 3840       1.171650e+09                      0.0
# 3841       2.086020e+09                      0.0
# 3842       7.353087e+09                      0.0
# 3843       9.852736e+09                      0.0
# 3844       6.759389e+09                      0.0
#
#       participações_da_controladora  passivo_fiscal_diferido  \
# 0                      1.371650e+07             2.400320e+05
# 1                      1.371650e+07             2.400320e+05
# 2                      1.660068e+07             0.000000e+00
# 3                      2.173569e+07             0.000000e+00
# 4                      2.596476e+07             0.000000e+00
# ...                             ...                      ...
# 3840                   7.385100e+07             7.369410e+08
# 3841                  -8.644700e+07             1.331332e+09
# 3842                   9.493495e+09             8.052892e+09
# 3843                   1.576811e+10             3.741901e+09
# 3844                  -2.363844e+09             4.263290e+09
#
#       passivos_circulantes  passivos_não_circulantes  patrimônio_líquido  \
# 0             8.454967e+06              2.891157e+06        4.940728e+07
# 1             8.454967e+06              2.891157e+06        4.940728e+07
# 2             9.124050e+06              3.021037e+06        6.090118e+07
# 3             1.227766e+07              3.465092e+06        7.528909e+07
# 4             1.573594e+07              4.088511e+06        9.151567e+07
# ...                    ...                       ...                 ...
# 3840          8.027850e+09              1.107750e+10        2.297220e+09
# 3841          9.501761e+09              1.974276e+10        6.181893e+09
# 3842          3.754040e+10              4.568359e+10        3.452053e+10
# 3843          4.556468e+10              4.111889e+10        5.554559e+10
# 3844          2.013762e+10              3.999954e+10        5.864756e+10
#
#       patrimônio_líquido_atribuível_aos_acionistas_da_controladora  \
# 0                                          4.940728e+07
# 1                                          4.940728e+07
# 2                                          6.090118e+07
# 3                                          7.528909e+07
# 4                                          9.151567e+07
# ...                                                 ...
# 3840                                       2.445149e+09
# 3841                                       6.310459e+09
# 3842                                       3.459482e+10
# 3843                                       5.544401e+10
# 3844                                       5.864710e+10
#
#       posição_cambial_líquida  posição_cambial_líquida_incluindo_hedge  \
# 0               -1.977267e+06                                      NaN
# 1               -1.977267e+06                                      NaN
# 2               -2.000179e+06                                      NaN
# 3                3.124046e+06                                      NaN
# 4                2.308966e+06                                      NaN
# ...                       ...                                      ...
# 3840            -8.388076e+09                            -8.527695e+09
# 3841            -1.515258e+10                            -1.496387e+10
# 3842            -2.924930e+10                            -2.909134e+10
# 3843            -2.947374e+10                            -2.947374e+10
# 3844            -2.796079e+10                            -2.796079e+10
#
#       posição_líquida_ativo_passivo_monetária_em_moeda_estrangeira  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3840                                      -8.397268e+09
# 3841                                      -1.525123e+10
# 3842                                      -2.940193e+10
# 3843                                      -2.965550e+10
# 3844                                      -2.802380e+10
#
#       provisões_de_longo_prazo  provisões_para_dívidas  \
# 0                          0.0                 71695.0
# 1                          0.0                 71695.0
# 2                          0.0                 71695.0
# 3                          0.0                 71695.0
# 4                          0.0                 71695.0
# ...                        ...                     ...
# 3840                44000000.0              13817000.0
# 3841                68296000.0              15540000.0
# 3842               288697000.0              35444000.0
# 3843               413527000.0             106508000.0
# 3844               444141000.0             127918000.0
#
#       receita_despesa_de_imposto_diferido  \
# 0                            1.659300e+05
# 1                            1.659300e+05
# 2                            1.492270e+05
# 3                            2.048030e+05
# 4                            2.324200e+05
# ...                                   ...
# 3840                         1.132400e+07
# 3841                         1.293890e+08
# 3842                        -2.421809e+09
# 3843                         9.509599e+09
# 3844                         4.905422e+09
#
#       receita_despesa_de_imposto_das_operações_continuadas  \
# 0                                         -3.107222e+06
# 1                                         -3.107222e+06
# 2                                         -4.197093e+06
# 3                                         -5.483481e+06
# 4                                         -6.586621e+06
# ...                                                 ...
# 3840                                      -1.064860e+08
# 3841                                       3.563800e+07
# 3842                                      -2.869153e+09
# 3843                                       8.809465e+09
# 3844                                       4.511967e+09
#
#       receita_despesa_de_imposto_do_período  receita_de_vendas  \
# 0                                -3273152.0       7.478781e+07
# 1                                -3273152.0       7.478781e+07
# 2                                -4346320.0       8.778961e+07
# 3                                -5688284.0       1.113844e+08
# 4                                -6819041.0       1.361230e+08
# ...                                     ...                ...
# 3840                           -117810000.0       8.579113e+09
# 3841                            -93751000.0       1.163481e+10
# 3842                           -447344000.0       3.880610e+10
# 3843                           -700134000.0       3.938931e+10
# 3844                           -393455000.0       2.965760e+10
#
#       receitas_financeiras_não_operacionais  \
# 0                              5.111900e+05
# 1                              5.111900e+05
# 2                              4.216040e+05
# 3                              9.681330e+05
# 4                              1.373916e+06
# ...                                     ...
# 3840                           9.817280e+08
# 3841                           2.516698e+09
# 3842                           8.832234e+09
# 3843                           1.328357e+10
# 3844                           4.910232e+09
#
#       receitas_de_atividades_de_investimento  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 3840                            7.188400e+07
# 3841                            2.098000e+06
# 3842                            6.251000e+06
# 3843                            5.993617e+09
# 3844                            4.825556e+09
#
#       reservas_restritas_separadas_do_lucro  total_de_ativos  \
# 0                                 2957664.0     6.075340e+07
# 1                                 2957664.0     6.075340e+07
# 2                                 4729678.0     7.304626e+07
# 3                                 5450104.0     9.103184e+07
# 4                                 6378203.0     1.113401e+08
# ...                                     ...              ...
# 3840                              7931000.0     2.140257e+10
# 3841                              7931000.0     3.542642e+10
# 3842                            100624000.0     1.177445e+11
# 3843                            145280000.0     1.422292e+11
# 3844                            145280000.0     1.187847e+11
#
#       total_do_passivo_e_patrimônico_líquido  \
# 0                               6.075340e+07
# 1                               6.075340e+07
# 2                               7.304626e+07
# 3                               9.103184e+07
# 4                               1.113401e+08
# ...                                      ...
# 3840                            2.140257e+10
# 3841                            3.542642e+10
# 3842                            1.177445e+11
# 3843                            1.422292e+11
# 3844                            1.187847e+11
#
#       valores_de_caixa_no_início_do_período  variação_nas_dívidas_financeiras  \
# 0                                       NaN                               NaN
# 1                                       NaN                               NaN
# 2                                       NaN                               NaN
# 3                                       NaN                               NaN
# 4                                       NaN                               NaN
# ...                                     ...                               ...
# 3840                           8.231210e+08                     -4.692610e+08
# 3841                           7.099090e+08                      5.478490e+08
# 3842                           3.205222e+09                      2.920434e+09
# 3843                           5.456515e+09                     -1.093341e+10
# 3844                           2.779085e+09                     -2.194924e+09
#
#       variação_no_caixa_e_equivalentes  vendas_domésticas  \
# 0                                  NaN         87260709.0
# 1                                  NaN         87260709.0
# 2                                  NaN        104427004.0
# 3                                  NaN        132355741.0
# 4                                  NaN        162911678.0
# ...                                ...                ...
# 3840                      -113212000.0                0.0
# 3841                       451735000.0                0.0
# 3842                       574086000.0                0.0
# 3843                      -532490000.0                0.0
# 3844                      -705924000.0                0.0
#
#       vendas_internacionais        ebitda ebitda_source  liquidez_corrente  \
# 0                 4865016.0  2.381818e+07     Estimated           5.391228
# 1                 4865016.0  2.381818e+07     Estimated           5.391228
# 2                 5399918.0  2.659145e+07     Estimated           6.424938
# 3                 6157158.0  3.328506e+07     Estimated           6.153521
# 4                 7611179.0  4.093322e+07     Estimated           5.940804
# ...                     ...           ...           ...                ...
# 3840                    0.0  1.910892e+09      Reported           0.504194
# 3841                    0.0  2.809507e+09      Reported           0.681064
# 3842                    0.0  2.409707e+09      Reported           0.601770
# 3843                    0.0  3.762464e+09      Reported           0.628254
# 3844                    0.0 -3.158172e+09      Reported           0.665920
#
#       liquidez_seca  divida_sobre_pl  divida_sobre_ativos       roe       roa  \
# 0          1.996632         0.035065             0.028516  0.277621  0.225773
# 1          1.996632         0.035065             0.028516  0.277621  0.225773
# 2          3.303575         0.023827             0.019865  0.272584  0.227263
# 3          3.524308         0.024994             0.020672  0.288696  0.238770
# 4          1.902564         0.023523             0.019334  0.283719  0.233202
# ...             ...              ...                  ...       ...       ...
# 3840       0.247193         3.165388             0.339753  0.032148  0.003451
# 3841       0.378006         1.923339             0.335622 -0.013984 -0.002440
# 3842       0.321508         0.820275             0.240489  0.275010  0.080628
# 3843       0.247363         0.552274             0.215683  0.283877  0.110864
# 3844       0.442821         0.389863             0.192487 -0.040306 -0.019900
#
#       margem_liquida  margem_operacional  giro_do_ativo  giro_de_estoque  \
# 0           0.183406            0.263879       1.231006        -2.743449
# 1           0.183406            0.263879       1.231006        -2.743449
# 2           0.189096            0.264218       1.201836        -3.485962
# 3           0.195141            0.270666       1.223576        -4.055084
# 4           0.190745            0.273883       1.222587        -2.524234
# ...              ...                 ...            ...              ...
# 3840        0.008608            0.141477       0.400845      -107.686291
# 3841       -0.007430            0.125758       0.328422       -81.761252
# 3842        0.244639            0.113481       0.329579       -56.472028
# 3843        0.400314            0.080205       0.276943       -88.525491
# 3844       -0.079705            0.059663       0.249675      -110.941730
#
#       giro_de_recebiveis  cobertura_de_juros  lucros_retidos_sobre_ativos  \
# 0              43.174808           -4.416966                     0.189012
# 1              43.174808           -4.416966                     0.189012
# 2              33.806376           -9.050283                     0.250811
# 3              24.933942          -12.144509                     0.294988
# 4              16.500857           -8.900462                     0.341168
# ...                  ...                 ...                          ...
# 3840           11.693908           -0.456485                    -0.045316
# 3841            8.029521           -0.267753                    -0.028656
# 3842            6.491898           -1.162218                     0.124824
# 3843            8.578741           -0.181168                     0.251601
# 3844            8.447728           -0.082522                     0.439776
#
#       razao_posicao_cambial  crescimento_vendas  crescimento_ativos  \
# 0                 -0.032546            0.000000            0.000000
# 1                 -0.032546            0.000000            0.000000
# 2                 -0.027382            0.173849            0.202340
# 3                  0.034318            0.268765            0.246222
# 4                  0.020738            0.222102            0.223090
# ...                     ...                 ...                 ...
# 3840              -0.391919            0.045698            0.145326
# 3841              -0.427720            0.356178            0.655241
# 3842              -0.248413            2.335345            2.323636
# 3843              -0.207227            0.015029            0.207947
# 3844              -0.235390           -0.247065           -0.164836
#
#       crescimento_lucro_liquido  margem_ebitda  ebitda_sobre_juros  \
# 0                      0.000000       0.318477           -5.330857
# 1                      0.000000       0.318477           -5.330857
# 2                      0.210271       0.302900          -10.375256
# 3                      0.309325       0.298831          -13.408221
# 4                      0.194568       0.300707           -9.772180
# ...                         ...            ...                 ...
# 3840                  -1.622454       0.222738           -0.718680
# 3841                  -2.170560       0.241474           -0.514127
# 3842                -110.818675       0.062096           -0.635957
# 3843                   0.660938       0.095520           -0.215762
# 3844                  -1.149913      -0.106488            0.147286
#
#       ebitda_sobre_divida  pontuacao_margem_ebitda  \
# 0               13.748112                       10
# 1               13.748112                       10
# 2               18.325388                       10
# 3               17.687981                       10
# 4               19.014982                       10
# ...                   ...                      ...
# 3840             0.262789                       10
# 3841             0.236294                       10
# 3842             0.085100                        3
# 3843             0.122650                        3
# 3844            -0.138125                        0
#
#       pontuacao_ebitda_sobre_juros  pontuacao_ebitda_sobre_divida  \
# 0                                0                             10
# 1                                0                             10
# 2                                0                             10
# 3                                0                             10
# 4                                0                             10
# ...                            ...                            ...
# 3840                             0                              8
# 3841                             0                              8
# 3842                             0                              5
# 3843                             0                              8
# 3844                             0                              0
#
#       pontuacao_roe  pontuacao_roa  pontuacao_margem_liquida  \
# 0                10             10                        10
# 1                10             10                        10
# 2                10             10                        10
# 3                10             10                        10
# 4                10             10                        10
# ...             ...            ...                       ...
# 3840              5              5                         5
# 3841              0              0                         0
# 3842             10              8                        10
# 3843             10             10                        10
# 3844              0              0                         0
#
#       pontuacao_margem_operacional  pontuacao_liquidez_corrente  \
# 0                               10                           10
# 1                               10                           10
# 2                               10                           10
# 3                               10                           10
# 4                               10                           10
# ...                            ...                          ...
# 3840                             8                            0
# 3841                             8                            0
# 3842                             8                            0
# 3843                             5                            0
# 3844                             5                            0
#
#       pontuacao_liquidez_seca  pontuacao_divida_sobre_pl  \
# 0                          10                         10
# 1                          10                         10
# 2                          10                         10
# 3                          10                         10
# 4                          10                         10
# ...                       ...                        ...
# 3840                        0                          0
# 3841                        0                          6
# 3842                        0                         10
# 3843                        0                         10
# 3844                        0                         10
#
#       pontuacao_divida_sobre_ativos  pontuacao_cobertura_de_juros  \
# 0                                10                             0
# 1                                10                             0
# 2                                10                             0
# 3                                10                             0
# 4                                10                             0
# ...                             ...                           ...
# 3840                             10                             0
# 3841                             10                             0
# 3842                             10                             0
# 3843                             10                             0
# 3844                             10                             0
#
#       pontuacao_lucros_retidos_sobre_ativos  pontuacao_giro_do_ativo  \
# 0                                         8                       10
# 1                                         8                       10
# 2                                         8                       10
# 3                                         8                       10
# 4                                        10                       10
# ...                                     ...                      ...
# 3840                                      0                        5
# 3841                                      0                        5
# 3842                                      8                        5
# 3843                                      8                        0
# 3844                                     10                        0
#
#       pontuacao_giro_de_estoque  pontuacao_giro_de_recebiveis  \
# 0                             0                            10
# 1                             0                            10
# 2                             0                            10
# 3                             0                            10
# 4                             0                            10
# ...                         ...                           ...
# 3840                          0                            10
# 3841                          0                             8
# 3842                          0                             8
# 3843                          0                             8
# 3844                          0                             8
#
#       pontuacao_crescimento_vendas  pontuacao_crescimento_ativos  \
# 0                                4                             4
# 1                                4                             4
# 2                               10                            10
# 3                               10                            10
# 4                               10                            10
# ...                            ...                           ...
# 3840                             4                             7
# 3841                            10                            10
# 3842                            10                            10
# 3843                             4                            10
# 3844                             0                             0
#
#       pontuacao_crescimento_lucro_liquido  pontuacao_razao_posicao_cambial  \
# 0                                       4                                5
# 1                                       4                                5
# 2                                      10                                5
# 3                                      10                                8
# 4                                       8                                8
# ...                                   ...                              ...
# 3840                                    0                                0
# 3841                                    0                                0
# 3842                                    0                                0
# 3843                                   10                                0
# 3844                                    0                                0
#
#       total_score
# 0            7.25
# 1            7.25
# 2            8.15
# 3            8.30
# 4            8.30
# ...           ...
# 3840         3.85
# 3841         3.75
# 3842         5.25
# 3843         5.30
# 3844         2.15
#
# [3845 rows x 128 columns]

# %%
'''
from ydata_profiling import ProfileReport

profile = ProfileReport(
    df_model,
    title="Credit Default EDA (Minimal)",
    explorative=True,   # less visual complexity, faster
    minimal=False,        
    progress_bar=True
)

profile.to_file("FINAL_EDA_MODEL.html")
print(" EDA report generated successfully: FINAL_EDA_MODEL.html")
'''
# Out:
# '\nfrom ydata_profiling import ProfileReport\n\nprofile = ProfileReport(\n    df_model,\n    title="Credit Default EDA (Minimal)",\n    explorative=True,   # less visual complexity, faster\n    minimal=False,        \n    progress_bar=True\n)\n\nprofile.to_file("FINAL_EDA_MODEL.html")\nprint(" EDA report generated successfully: FINAL_EDA_MODEL.html")\n'

# %%
df_corr = df_model.copy()
df_corr = df_corr.drop(columns=['companycode', 'ano'])

# %%
# Calculate correlation matrix
corr_matrix = df_corr.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 # Calculate correlation matrix
# ----> 2 corr_matrix = df_corr.corr()
#
# File c:\Users\gregorio\TCC-CD-USP\venv\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\gregorio\TCC-CD-USP\venv\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\gregorio\TCC-CD-USP\venv\Lib\site-packages\pandas\core\internals\managers.py:1713, in BlockManager.as_array(self, dtype, copy, na_value)
#    1711         arr.flags.writeable = False
#    1712 else:
# -> 1713     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1714     # The underlying data was copied within _interleave, so no need
#    1715     # to further copy if copy=True or setting na_value
#    1717 if na_value is lib.no_default:
#
# File c:\Users\gregorio\TCC-CD-USP\venv\Lib\site-packages\pandas\core\internals\managers.py:1772, in BlockManager._interleave(self, dtype, na_value)
#    1770     else:
#    1771         arr = blk.get_values(dtype)
# -> 1772     result[rl.indexer] = arr
#    1773     itemmask[rl.indexer] = 1
#    1775 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Estimated'

# %%
corrs=corr_matrix.loc['total_score'].drop('total_score').sort_values(ascending=False)
corrs

# %%
import phik
from phik import resources, report
phi_k_corr = df_corr.phik_matrix()
phi_k_corr

# %%
phik_corrs=phi_k_corr.loc['total_score'].drop('total_score').sort_values(ascending=False)
phik_corrs

# %%
df_model=df_model.drop(columns=['pontuacao_margem_ebitda',
'pontuacao_ebitda_sobre_juros',
'pontuacao_ebitda_sobre_divida',
'pontuacao_roe',
'pontuacao_roa',
'pontuacao_margem_liquida',
'pontuacao_margem_operacional',
'pontuacao_liquidez_corrente',
'pontuacao_liquidez_seca',
'pontuacao_divida_sobre_pl',
'pontuacao_divida_sobre_ativos',
'pontuacao_cobertura_de_juros',
'pontuacao_lucros_retidos_sobre_ativos',
'pontuacao_giro_do_ativo',
'pontuacao_giro_de_estoque',
'pontuacao_giro_de_recebiveis',
'pontuacao_crescimento_vendas',
'pontuacao_crescimento_ativos',
'pontuacao_crescimento_lucro_liquido',
'pontuacao_razao_posicao_cambial'],axis=1)

# %%
df_model

# %%
df_model.columns.tolist()

# %%
df_model.to_csv('C:/Users/gregorio/TCC-CD-USP/archives/df_model.csv', index=False)
